# %% [markdown]
# # Notebook 02: Obtain, Store, and Clean the Watergate Special Prosecution Force Transcripts
#
# **Project: Data Triage of Transcribed Nixon Tapes** <br>
# *Michelle Ballard and April Crompton* <br>
# Loyola University Maryland Data Science Project

# %% [markdown]
# ## Import statements

# %%
import pickle
import pprint
import re
import sys
from collections import Counter, defaultdict
from datetime import date, datetime, time, timedelta # to capture date and time metadata

import pandas as pd
import requests
from bs4 import BeautifulSoup

import pdfplumber

# %% [markdown]
# ## Obtain Watergate Special Prosecution Force Data

# %% [markdown]
# ### Retrieve page content from the Nixon Library website

# %%
response=requests.get("https://www.nixonlibrary.gov/watergate-special-prosecution-force-transcripts")
if response.status_code == requests.codes.ALL_OK:
    # Process the page
    page = BeautifulSoup(response.content)
else: print(response.status_code)

print("Files Last Updated:", (date.today()))
# Out:
# Files Last Updated: 2022-04-16

# %%
# Store data relevant to each exhibit 
all_h3 = page.find_all("h3")  # exhibit metadata DATEs
all_pdfs = page.find_all("a", href=True)  # exhibit transcripts

# %% [markdown]
# ### Process exhibit metadata

# %% [markdown]
# #### Acquire metadata per exhibit from the web page

# %%
# Determine metadata categories
# ref: rtphokie https://stackoverflow.com/questions/11647348/find-next-siblings-until-a-certain-one-using-beautifulsoup

# collect the metadata categories within each section
category_titles = []
for i in all_h3: # each dated section is in h3; metadata falls within dated sections
    for sib in i.next_siblings:
        if sib.name == 'h3':
            break
        else: 
            try:
                text_list = [t.text.strip() for t in sib.findAll("strong") if len(t.text)>1]
                category_titles.extend(text_list)
            except: continue

cat_dict = Counter(category_titles) # counter dict of all categories
idxln = max(cat_dict.values()) # number of records to expect
category_titles = [k for k, v in Counter(category_titles).items() if v>1]  # this removed single occurences of strong text
print("Categories:", category_titles)
print("Number of records:", idxln)
# Out:
# Categories: ['Cassette Number / Minutes:', 'Conversation Number:', 'Location:', 'Participants:']
# Number of records: 88

# %%
# create a dataframe for metadata
df_meta = pd.DataFrame(columns=(*category_titles,"txtdate","exhibit_number"), index=([i for i in range(idxln)])) #Create a blank DF with column titles

# %%
# Populate the Dataframe with Metadata

it = 0
expatt = re.compile(r".+\.pdf")

for i in all_h3: # each dated section is in h3; metadata falls within dated sections
    k = i.text[8:].strip() # capture date
    for sib in i.next_siblings:
        if sib.name == 'h3': # 'h3' denotes a new dated section
            break
        else:
            # identify which exhibit is in the current segment
            exhib = re.findall(expatt, str(sib))
            if len(exhib)>0:
                exhibit = exhib[-1].split('>')[-1][:-4] # use the name between > and .pdf
            row = it # update the DF row to put the new info into
            for n in range(len(category_titles)): # see which column heading in the DF to update
                try:
                    ts = re.search(category_titles[n],sib.text).span()[1] # find the start of the value to update
                    # If it's acknowledged the Location column,
                    #  Populate the TextDate and exhibit number on the current row
                    #  Prepare for the next row in the dataframe
                    if n==2 and re.search(category_titles[n],sib.text).span()[1]>0:
                        df_meta.update(pd.DataFrame({"txtdate": [k],
                                                     "exhibit_number": exhibit}, index = [row]))
                        it +=1 # Iterate the next row in the dataframe each time the 0'th column is identified
                    try:
                        te = re.search(category_titles[n+1],sib.text).span()[0] # find the end of the value to update
                    except: te=None
                except: continue
                df_meta.update(pd.DataFrame({category_titles[n]: [sib.text[ts+1:te].strip().replace(u'\t',"")]}, index=[row]))

# %%
# rename columns for best practices
new_names = {k:k.strip().replace(':','').replace(' ','_').lower() for k in df_meta.columns}
df_meta.rename(columns=new_names, inplace=True)

# %%
# Check for duplicates
print(len(df_meta['exhibit_number'].unique()) < len(df_meta.index))

# Drop records without Transcripts
df_meta.drop(df_meta[df_meta['cassette_number_/_minutes'].str.contains("Not")].index,
             axis=0, inplace=True)

# re-check for duplicates
print(len(df_meta['exhibit_number'].unique()) < len(df_meta.index))
# Out:
# True
# False

# %%
# Set Row Index to exhibit
df_meta.set_index(['exhibit_number'], inplace=True)

# %%
# Review the df_meta DataFrame
pd.options.display.max_rows = 1000
display(df_meta)
pd.reset_option("display.max_rows")
# Out:
#                                                  cassette_number_/_minutes  \
# exhibit_number
# 472-004_472-005_472-006                                 E - 25 (3 minutes)
# 051-001                           E - 26 (49 minutes)  [Concludes on E-27]
# 472-021                                                E - 28 (31 minutes)
# 482-017_482-018                                        E - 29 (31 minutes)
# 002-001_002-002                                          E - 30 (1 minute)
# 485-004                                                 E - 31 (3 minutes)
# 491-014                                                E - 32 (28 minutes)
# 538-015                                                E - 33 (19 minutes)
# 545-003                                                E - 34 (12 minutes)
# 587-003                                                 E - 35 (9 minutes)
# 601-033                                                E - 36 (26 minutes)
# 697-015                                                E - 37 (25 minutes)
# 697-029                                                E - 38 (46 minutes)
# 342-027                                                E - 40 (21 minutes)
# 741-002                          E - 41 (54 minutes)   [Concludes on E-42]
# 741-010                                                 E - 43 (4 minutes)
# 343-036                                                E - 44 (23 minutes)
# 347-004                                                 E - 45 (3 minutes)
# 779-002                          E - 46 (48 minutes)   [Concludes on E-47]
# 000-000_35d                                            E - 48 (18 minutes)
# 393-013_393-014                                        E - 49 (25 minutes)
# 394-021_395-001                                        E - 51 (23 minutes)
# 854-017                                                E - 52 (12 minutes)
# 855-010                                                E - 53 (20 minutes)
# 856-004                                                E - 54 (16 minutes)
# 858-003                                                E - 55 (29 minutes)
# 862-004                                                E - 56 (22 minutes)
# 862-006                                                E - 57 (44 minutes)
# 864-004                                                 E - 58 (3 minutes)
# 865-014                          E - 59 (56 minutes)   [Concludes on E-60]
# 866-003                                                 E -61 (26 minutes)
# 872-001                                                 E - 62 (4 minutes)
# 878-014                          E - 63 (69 minutes)   [Concludes on E-64]
# 882-012                                                E - 65 (33 minutes)
# 884-007                                                 E - 66 (4 minutes)
# 885-007                                                E - 67 (46 minutes)
# 037-175_037-176                                        E - 68 (14 minutes)
# 886-008                  E - 69 (111 minutes)   [Continues on E-70 and ...
# 421-018                                                E - 72 (36 minutes)
# 037-204_037-205                                        E - 73 (14 minutes)
# 422-020                         E - 74 (106 minutes)   [Concludes on E-75]
# 422-033                          E - 76 (88 minutes)   [Concludes on E-77]
# 423-003                  E - 78 (109 minutes)   [Continues on E-79 and ...
# 890-019                                                E - 81 (16 minutes)
# 044-158                                                E - 82 (15 minutes)
# 428-019                  E - 83 (126 minutes)   [Continues on E-84 and ...
# 896-004                                                E - 86 (47 minutes)
# 896-005                                                E - 87 (43 minutes)
# 428-028                          E - 88 (57 minutes)   [Concludes on E-89]
# 038-034                                                E - 90 (12 minutes)
# 038-037                                                E - 91 (29 minutes)
# 896-006                                                E - 92 (31 minutes)
# 038-042_038-043                                        E - 93 (18 minutes)
# 897-003                                                E - 94 (19 minutes)
# 897-004                                                E - 95 (37 minutes)
# 897-009                                                E - 96 (12 minutes)
# 897-011                                                E - 97 (22 minutes)
# 427-005_427-006                                        E - 98 (29 minutes)
# 427-010                                                E - 99 (19 minutes)
# 898-006                                               E - 100 (11 minutes)
# 898-012                  E - 101 (107 minutes)   [Continues on E-102 an...
# 898-023_899-001                                       E - 104 (43 minutes)
# 429-003                         E - 105 (94 minutes)   [Conclues on E-106]
# 900-026                                               E - 107 (18 minutes)
# 902-001                                               E - 108 (34 minutes)
# 902-002_902-003                                       E - 109 (11 minutes)
# 902-009                                               E - 110 (30 minutes)
# 429-015                        E - 111 (71 minutes)   [Continues on E-112]
# 000-000_37d                                           E - 113 (10 minutes)
# 429-018                                               E - 114 (26 minutes)
# 038-125_038-126                                       E - 115 (15 minutes)
# 903-001                                               E - 116 (16 minutes)
# 903-006                                               E - 117 (22 minutes)
# 903-019                                               E - 118 (17 minutes)
# 430-004                  E - 119 (150 minutes)   [Continues on E-120, E...
# 430-022                                               E - 123 (42 minutes)
# 038-150                                               E - 124 (17 minutes)
# 038-151                                                E - 125 (2 minutes)
# 038-154_038-155                                       E - 126 (14 minutes)
# 038-156_038-157                                        E - 127 (8 minutes)
# 905-008                        E - 128 (89 minutes)   [Concludes on E-129]
# 431-009                  E - 130 (309 minutes)   [Continues on E-131 - ...
# 442-001-069              E - 137 (281 minutes)   [Continues on E-138 - ...
# 039-080_039-081                                       E - 144 (15 minutes)
# 039-083                                                 E - 145 (1 minute)
#
#                         conversation_number  \
# exhibit_number
# 472-004_472-005_472-006             472-004
# 051-001                             051-001
# 472-021                             472-021
# 482-017_482-018                     482-017
# 002-001_002-002                     002-001
# 485-004                             485-004
# 491-014                             491-014
# 538-015                             538-015
# 545-003                             545-003
# 587-003                             587-003
# 601-033                             601-033
# 697-015                             697-015
# 697-029                             697-029
# 342-027                             342-027
# 741-002                             741-002
# 741-010                             741-010
# 343-036                             343-036
# 347-004                             347-004
# 779-002                             779-002
# 000-000_35d                             NaN
# 393-013_393-014                     393-013
# 394-021_395-001             394-021/395-001
# 854-017                             854-017
# 855-010                             855-010
# 856-004                             856-004
# 858-003                             858-003
# 862-004                             862-004
# 862-006                             862-006
# 864-004                             864-004
# 865-014                             865-014
# 866-003                             866-003
# 872-001                             872-001
# 878-014                             878-014
# 882-012                             882-012
# 884-007                             884-007
# 885-007                             885-007
# 037-175_037-176                     037-175
# 886-008                             886-008
# 421-018                             421-018
# 037-204_037-205                     037-204
# 422-020                             422-020
# 422-033                             422-033
# 423-003                             423-003
# 890-019                             890-019
# 044-158                             044-158
# 428-019                             428-019
# 896-004                             896-004
# 896-005                             896-005
# 428-028                             428-028
# 038-034                             038-034
# 038-037                             038-037
# 896-006                             896-006
# 038-042_038-043                     038-042
# 897-003                             897-003
# 897-004                             897-004
# 897-009                             897-009
# 897-011                             897-011
# 427-005_427-006                     427-005
# 427-010                             427-010
# 898-006                             898-006
# 898-012                             898-012
# 898-023_899-001             898-023/899-001
# 429-003                             429-003
# 900-026                             900-026
# 902-001                             902-001
# 902-002_902-003                     902-002
# 902-009                             902-009
# 429-015                             429-015
# 000-000_37d                             NaN
# 429-018                             429-018
# 038-125_038-126                     038-125
# 903-001                             903-001
# 903-006                             903-006
# 903-019                             903-019
# 430-004                             430-004
# 430-022                             430-022
# 038-150                             038-150
# 038-151                             038-151
# 038-154_038-155                     038-154
# 038-156_038-157                     038-156
# 905-008                             905-008
# 431-009                             431-009
# 442-001-069                         442-001
# 039-080_039-081                     039-080
# 039-083                             039-083
#
#                                                      location  \
# exhibit_number
# 472-004_472-005_472-006               White House Oval Office
# 051-001                                          Cabinet Room
# 472-021                               White House Oval Office
# 482-017_482-018                       White House Oval Office
# 002-001_002-002                         White House Telephone
# 485-004                               White House Oval Office
# 491-014                               White House Oval Office
# 538-015                               White House Oval Office
# 545-003                               White House Oval Office
# 587-003                               White House Oval Office
# 601-033                               White House Oval Office
# 697-015                               White House Oval Office
# 697-029                               White House Oval Office
# 342-027                  Old Executive Office Building Office
# 741-002                               White House Oval Office
# 741-010                               White House Oval Office
# 343-036                  Old Executive Office Building Office
# 347-004                  Old Executive Office Building Office
# 779-002                               White House Oval Office
# 000-000_35d                             [Dictabelt Recording]
# 393-013_393-014          Old Executive Office Building Office
# 394-021_395-001          Old Executive Office Building Office
# 854-017                               White House Oval Office
# 855-010                               White House Oval Office
# 856-004                               White House Oval Office
# 858-003                               White House Oval Office
# 862-004                               White House Oval Office
# 862-006                               White House Oval Office
# 864-004                               White House Oval Office
# 865-014                               White House Oval Office
# 866-003                               White House Oval Office
# 872-001                               White House Oval Office
# 878-014                               White House Oval Office
# 882-012                               White House Oval Office
# 884-007                               White House Oval Office
# 885-007                               White House Oval Office
# 037-175_037-176                         White House Telephone
# 886-008                               White House Oval Office
# 421-018                  Old Executive Office Building Office
# 037-204_037-205                         White House Telephone
# 422-020                  Old Executive Office Building Office
# 422-033                  Old Executive Office Building Office
# 423-003                  Old Executive Office Building Office
# 890-019                               White House Oval Office
# 044-158                                 White House Telephone
# 428-019                  Old Executive Office Building Office
# 896-004                               White House Oval Office
# 896-005                               White House Oval Office
# 428-028                  Old Executive Office Building Office
# 038-034                                 White House Telephone
# 038-037                                 White House Telephone
# 896-006                               White House Oval Office
# 038-042_038-043                         White House Telephone
# 897-003                               White House Oval Office
# 897-004                               White House Oval Office
# 897-009                               White House Oval Office
# 897-011                               White House Oval Office
# 427-005_427-006                 Old Executive Office Building
# 427-010                         Old Executive Office Building
# 898-006                               White House Oval Office
# 898-012                               White House Oval Office
# 898-023_899-001                       White House Oval Office
# 429-003                         Old Executive Office Building
# 900-026                               White House Oval Office
# 902-001                               White House Oval Office
# 902-002_902-003                       White House Oval Office
# 902-009                               White House Oval Office
# 429-015                         Old Executive Office Building
# 000-000_37d                             [Dictabelt Recording]
# 429-018                         Old Executive Office Building
# 038-125_038-126                         White House Telephone
# 903-001                               White House Oval Office
# 903-006                               White House Oval Office
# 903-019                               White House Oval Office
# 430-004                         Old Executive Office Building
# 430-022                         Old Executive Office Building
# 038-150                                 White House Telephone
# 038-151                                 White House Telephone
# 038-154_038-155                         White House Telephone
# 038-156_038-157                         White House Telephone
# 905-008                               White House Oval Office
# 431-009                         Old Executive Office Building
# 442-001-069                     Old Executive Office Building
# 039-080_039-081                         White House Telephone
# 039-083                                 White House Telephone
#
#                                                               participants  \
# exhibit_number
# 472-004_472-005_472-006                   President Nixon; Stephen B. Bull
# 051-001                     President Nixon; Leaders of the Dairy Industry
# 472-021                  President Nixon; John B. Connally; John D. Ehr...
# 482-017_482-018          President Nixon; John D, Ehrlichman; George P....
# 002-001_002-002                    President Nixon; Richard G. Kleindienst
# 485-004                                  President Nixon; John N. Mitchell
# 491-014                            President Nixon; H. R. ("Bob") Haldeman
# 538-015                  President Nixon; John N. Mitchell; John D. Ehr...
# 545-003                  President Nixon; John D. Ehrlichman; Egil ("Bu...
# 587-003                  President Nixon; John N. Mitchell; John D. Ehr...
# 601-033                  President Nixon; John D. Ehrlichman; Stephen B...
# 697-015                            President Nixon; H. R. ("Bob") Haldeman
# 697-029                  President Nixon; H. R. ("Bob") Haldeman; Charl...
# 342-027                                 President Nixon; Charles W. Colson
# 741-002                  President Nixon; H. R. ("Bob") Haldeman; Ronal...
# 741-010                            President Nixon; H. R. ("Bob") Haldeman
# 343-036                  President Nixon; H. R. ("Bob") Haldeman; Ronal...
# 347-004                  President Nixon; John N. Mitchell; H. R. ("Bob...
# 779-002                  President Nixon; H. R. ("Bob") Haldeman; John ...
# 000-000_35d                              Charles W. Colson; E. Howard Hunt
# 393-013_393-014                         President Nixon; Charles W. Colson
# 394-021_395-001                         President Nixon; Charles W. Colson
# 854-017                                 President Nixon; Charles W. Colson
# 855-010                  President Nixon; Charles W. Colson; Stephen B....
# 856-004                                President Nixon; John D. Ehrlichman
# 858-003                  President Nixon; John D. Ehrlichman; L. Patric...
# 862-004                  President Nixon; John D. Ehrlichman; Stephen B...
# 862-006                            President Nixon; Richard G. Kleindienst
# 864-004                  President Nixon; John W, Dean, III; Stephen B....
# 865-014                  President Nixon; John W, Dean, III; Stephen B....
# 866-003                  President Nixon; John W. Dean, III; Manolo San...
# 872-001                                 President Nixon; John W. Dean, III
# 878-014                  President Nixon; H. R. ("Bob") Haldeman;  John...
# 882-012                  President Nixon; John W. Dean, III; H. R. ("Bo...
# 884-007                            President Nixon; H. R. ("Bob") Haldeman
# 885-007                            President Nixon; H. R. ("Bob") Haldeman
# 037-175_037-176          President Nixon; John W. Dean, III; White Hous...
# 886-008                  President Nixon; John W, Dean, III; H. R. ("Bo...
# 421-018                  President Nixon; John W. Dean, III; H. R. ("Bo...
# 037-204_037-205          President Nixon; Charles W. Colson; White Hous...
# 422-020                            President Nixon; H. R. ("Bob") Haldeman
# 422-033                  President Nixon; John W. Dean, III; John D. Eh...
# 423-003                  President Nixon; H. R. ("Bob") Haldeman; John ...
# 890-019                  President Nixon; Ronald L. Ziegler; John D. Eh...
# 044-158                                 President Nixon; Charles W. Colson
# 428-019                  President Nixon; H. R. ("Bob") Haldeman; John ...
# 896-004                  President Nixon; H. R. ("Bob") Haldeman; John ...
# 896-005                  President Nixon; H. R. ("Bob") Haldeman; John ...
# 428-028                  President Nixon; H. R. ("Bob") Haldeman; John ...
# 038-034                            President Nixon; H. R. ("Bob") Haldeman
# 038-037                                President Nixon; John D. Ehrlichman
# 896-006                  President Nixon; John D. Ehrlichman; Manolo Sa...
# 038-042_038-043          President Nixon; H. R. ("Bob") Haldeman; John ...
# 897-003                  President Nixon; H. R. ("Bob") Haldeman; John ...
# 897-004                  President Nixon; John W. Dean, III; Stephen B....
# 897-009                  President Nixon; H. R. ("Bob") Haldeman; John ...
# 897-011                            President Nixon; H. R. ("Bob") Haldeman
# 427-005_427-006          President Nixon; Ronald L. Ziegler; John D. Eh...
# 427-010                                 President Nixon; John W. Dean, III
# 898-006                  President Nixon; H. R. ("Bob") Haldeman; Rose ...
# 898-012                  President Nixon; H. R. ("Bob") Haldeman; John ...
# 898-023_899-001          President Nixon; H. R. ("Bob") Haldeman; Ronal...
# 429-003                  President Nixon; William P. Rogers; H. R. ("Bo...
# 900-026                                President Nixon; John D. Ehrlichman
# 902-001                  President Nixon; H. R. ("Bob") Haldeman; John ...
# 902-002_902-003                         President Nixon; Henry E. Petersen
# 902-009                                President Nixon; John D. Ehrlichman
# 429-015                                  President Nixon; Richard A. Moore
# 000-000_37d                        John D. Ehrlichman; Herbert W. Kalmbach
# 429-018                  President Nixon; John D. Ehrlichman; Manolo Sa...
# 038-125_038-126          President Nixon; H. R. ("Bob") Haldeman; White...
# 903-001                            President Nixon; H. R. ("Bob") Haldeman
# 903-006                            President Nixon; H. R. ("Bob") Haldeman
# 903-019                  President Nixon; H. R. ("Bob") Haldeman; John ...
# 430-004                  President Nixon; H. R. ("Bob") Haldeman; John ...
# 430-022                            President Nixon; H. R. ("Bob") Haldeman
# 038-150                            President Nixon; H. R. ("Bob") Haldeman
# 038-151                                President Nixon; John D. Ehrlichman
# 038-154_038-155          President Nixon; John D. Ehrlichman; White Hou...
# 038-156_038-157          President Nixon; H. R. ("Bob") Haldeman; White...
# 905-008                            President Nixon; H. R. ("Bob") Haldeman
# 431-009                  President Nixon; H. R. ("Bob") Haldeman; John ...
# 442-001-069              President Nixon; John W. Dean, III; Stephen B....
# 039-080_039-081          President Nixon; H. R. ("Bob") Haldeman; White...
# 039-083                            President Nixon; H. R. ("Bob") Haldeman
#
#                                     txtdate
# exhibit_number
# 472-004_472-005_472-006      March 23, 1971
# 051-001                      March 23, 1971
# 472-021                      March 23, 1971
# 482-017_482-018              April 19, 1971
# 002-001_002-002              April 19, 1971
# 485-004                      April 21, 1971
# 491-014                         May 5, 1971
# 538-015                        July 6, 1971
# 545-003                       July 24, 1971
# 587-003                     October 8, 1971
# 601-033                    October 25, 1971
# 697-015                      March 30, 1972
# 697-029                      March 30, 1972
# 342-027                       June 20, 1972
# 741-002                       June 23, 1972
# 741-010                       June 23, 1972
# 343-036                       June 23, 1972
# 347-004                       June 30, 1972
# 779-002                  September 15, 1972
# 000-000_35d                         Unknown
# 393-013_393-014             January 4, 1973
# 394-021_395-001             January 8, 1973
# 854-017                   February 13, 1973
# 855-010                   February 14, 1973
# 856-004                   February 14, 1973
# 858-003                   February 16, 1973
# 862-004                   February 23, 1973
# 862-006                   February 23, 1973
# 864-004                   February 27, 1973
# 865-014                   February 28, 1973
# 866-003                       March 1, 1973
# 872-001                       March 8, 1973
# 878-014                      March 13, 1973
# 882-012                      March 17, 1973
# 884-007                      March 20, 1973
# 885-007                      March 20, 1973
# 037-175_037-176              March 20, 1973
# 886-008                      March 20, 1973
# 421-018                      March 20, 1973
# 037-204_037-205              March 20, 1973
# 422-020                      March 22, 1973
# 422-033                      March 22, 1973
# 423-003                      March 27, 1973
# 890-019                      March 30, 1973
# 044-158                      April 12, 1973
# 428-019                      April 14, 1973
# 896-004                      April 14, 1973
# 896-005                      April 14, 1973
# 428-028                      April 14, 1973
# 038-034                      April 14, 1973
# 038-037                      April 14, 1973
# 896-006                      April 15, 1973
# 038-042_038-043              April 15, 1973
# 897-003                      April 16, 1973
# 897-004                      April 16, 1973
# 897-009                      April 16, 1973
# 897-011                      April 16, 1973
# 427-005_427-006              April 16, 1973
# 427-010                      April 16, 1973
# 898-006                      April 17, 1973
# 898-012                      April 17, 1973
# 898-023_899-001              April 17, 1973
# 429-003                      April 17, 1973
# 900-026                      April 18, 1973
# 902-001                      April 19, 1973
# 902-002_902-003              April 19, 1973
# 902-009                      April 19, 1973
# 429-015                      April 19, 1973
# 000-000_37d                         Unknown
# 429-018                      April 19, 1973
# 038-125_038-126              April 19, 1973
# 903-001                      April 20, 1973
# 903-006                      April 20, 1973
# 903-019                      April 20, 1973
# 430-004                      April 25, 1973
# 430-022                      April 25, 1973
# 038-150                      April 25, 1973
# 038-151                      April 25, 1973
# 038-154_038-155              April 25, 1973
# 038-156_038-157              April 25, 1973
# 905-008                      April 26, 1973
# 431-009                      April 26, 1973
# 442-001-069                    June 4, 1973
# 039-080_039-081                June 4, 1973
# 039-083                        June 4, 1973

# %% [markdown]
# #### Perform initial datagrooming on exhibit metadata

# %%
# Parse the Cassette number and Minutes, update dataframe
def cnm(text):
    epatt = re.compile('\d{1,3}') # assumes no conference is over 999 minutes and no exhibit is higher than 999
    result = re.findall(epatt, text)
    eresult = [result[0]] # assumes exhibit numbers are the first and 3rd+ digits in the text
    if len(text)>2: eresult.extend(result[2:])
    eresult = ["E-"+str(e) for e in eresult]
    mresult = result[1] # assumes minutes is the second digit in the text
    return eresult, mresult

dfmmeta = df_meta['cassette_number_/_minutes'].apply(lambda x: cnm(x))
df_meta['cassette_number'] = dfmmeta.apply(lambda x: x[0])
df_meta['minutes'] = dfmmeta.apply(lambda x: x[1])

# %%
# Make Participants a list
def part(text):
    p = text.replace('\xa0','').strip().split(';')
    return p

df_meta['participants'] = df_meta['participants'].apply(lambda x: part(x))

# %%
# Add Date field with datetime value of text date
def fixdate(txtdate):
    try: dt = pd.to_datetime(txtdate) 
    except: dt=None
    return dt

df_meta['date'] = df_meta['txtdate'].apply(lambda x: fixdate(x))

# %%
# Manage Exceptions:

#  Dictabelt recordings do not show date or conversation number.
#  Use exhibit ID for conversation, and pdf doc dates. select 1st of the month for 11/1972

df_meta.update(pd.DataFrame({'conversation_number': ['35d', '37d'],
                'date':[pd.to_datetime("11/01/1972"), pd.to_datetime("04/18/1973")]},
               index=['000-000_35d', '000-000_37d']), overwrite=True)

# %%
# review full DataFrame
df_meta.info()
pd.options.display.max_rows = 1000
display(df_meta)
pd.reset_option("display.max_rows")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 85 entries, 472-004_472-005_472-006 to 039-083
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   cassette_number_/_minutes  85 non-null     object
#  1   conversation_number        85 non-null     object
#  2   location                   85 non-null     object
#  3   participants               85 non-null     object
#  4   txtdate                    85 non-null     object
#  5   cassette_number            85 non-null     object
#  6   minutes                    85 non-null     object
#  7   date                       85 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), object(7)
# memory usage: 6.0+ KB
#                                                  cassette_number_/_minutes  \
# exhibit_number
# 472-004_472-005_472-006                                 E - 25 (3 minutes)
# 051-001                           E - 26 (49 minutes)  [Concludes on E-27]
# 472-021                                                E - 28 (31 minutes)
# 482-017_482-018                                        E - 29 (31 minutes)
# 002-001_002-002                                          E - 30 (1 minute)
# 485-004                                                 E - 31 (3 minutes)
# 491-014                                                E - 32 (28 minutes)
# 538-015                                                E - 33 (19 minutes)
# 545-003                                                E - 34 (12 minutes)
# 587-003                                                 E - 35 (9 minutes)
# 601-033                                                E - 36 (26 minutes)
# 697-015                                                E - 37 (25 minutes)
# 697-029                                                E - 38 (46 minutes)
# 342-027                                                E - 40 (21 minutes)
# 741-002                          E - 41 (54 minutes)   [Concludes on E-42]
# 741-010                                                 E - 43 (4 minutes)
# 343-036                                                E - 44 (23 minutes)
# 347-004                                                 E - 45 (3 minutes)
# 779-002                          E - 46 (48 minutes)   [Concludes on E-47]
# 000-000_35d                                            E - 48 (18 minutes)
# 393-013_393-014                                        E - 49 (25 minutes)
# 394-021_395-001                                        E - 51 (23 minutes)
# 854-017                                                E - 52 (12 minutes)
# 855-010                                                E - 53 (20 minutes)
# 856-004                                                E - 54 (16 minutes)
# 858-003                                                E - 55 (29 minutes)
# 862-004                                                E - 56 (22 minutes)
# 862-006                                                E - 57 (44 minutes)
# 864-004                                                 E - 58 (3 minutes)
# 865-014                          E - 59 (56 minutes)   [Concludes on E-60]
# 866-003                                                 E -61 (26 minutes)
# 872-001                                                 E - 62 (4 minutes)
# 878-014                          E - 63 (69 minutes)   [Concludes on E-64]
# 882-012                                                E - 65 (33 minutes)
# 884-007                                                 E - 66 (4 minutes)
# 885-007                                                E - 67 (46 minutes)
# 037-175_037-176                                        E - 68 (14 minutes)
# 886-008                  E - 69 (111 minutes)   [Continues on E-70 and ...
# 421-018                                                E - 72 (36 minutes)
# 037-204_037-205                                        E - 73 (14 minutes)
# 422-020                         E - 74 (106 minutes)   [Concludes on E-75]
# 422-033                          E - 76 (88 minutes)   [Concludes on E-77]
# 423-003                  E - 78 (109 minutes)   [Continues on E-79 and ...
# 890-019                                                E - 81 (16 minutes)
# 044-158                                                E - 82 (15 minutes)
# 428-019                  E - 83 (126 minutes)   [Continues on E-84 and ...
# 896-004                                                E - 86 (47 minutes)
# 896-005                                                E - 87 (43 minutes)
# 428-028                          E - 88 (57 minutes)   [Concludes on E-89]
# 038-034                                                E - 90 (12 minutes)
# 038-037                                                E - 91 (29 minutes)
# 896-006                                                E - 92 (31 minutes)
# 038-042_038-043                                        E - 93 (18 minutes)
# 897-003                                                E - 94 (19 minutes)
# 897-004                                                E - 95 (37 minutes)
# 897-009                                                E - 96 (12 minutes)
# 897-011                                                E - 97 (22 minutes)
# 427-005_427-006                                        E - 98 (29 minutes)
# 427-010                                                E - 99 (19 minutes)
# 898-006                                               E - 100 (11 minutes)
# 898-012                  E - 101 (107 minutes)   [Continues on E-102 an...
# 898-023_899-001                                       E - 104 (43 minutes)
# 429-003                         E - 105 (94 minutes)   [Conclues on E-106]
# 900-026                                               E - 107 (18 minutes)
# 902-001                                               E - 108 (34 minutes)
# 902-002_902-003                                       E - 109 (11 minutes)
# 902-009                                               E - 110 (30 minutes)
# 429-015                        E - 111 (71 minutes)   [Continues on E-112]
# 000-000_37d                                           E - 113 (10 minutes)
# 429-018                                               E - 114 (26 minutes)
# 038-125_038-126                                       E - 115 (15 minutes)
# 903-001                                               E - 116 (16 minutes)
# 903-006                                               E - 117 (22 minutes)
# 903-019                                               E - 118 (17 minutes)
# 430-004                  E - 119 (150 minutes)   [Continues on E-120, E...
# 430-022                                               E - 123 (42 minutes)
# 038-150                                               E - 124 (17 minutes)
# 038-151                                                E - 125 (2 minutes)
# 038-154_038-155                                       E - 126 (14 minutes)
# 038-156_038-157                                        E - 127 (8 minutes)
# 905-008                        E - 128 (89 minutes)   [Concludes on E-129]
# 431-009                  E - 130 (309 minutes)   [Continues on E-131 - ...
# 442-001-069              E - 137 (281 minutes)   [Continues on E-138 - ...
# 039-080_039-081                                       E - 144 (15 minutes)
# 039-083                                                 E - 145 (1 minute)
#
#                         conversation_number  \
# exhibit_number
# 472-004_472-005_472-006             472-004
# 051-001                             051-001
# 472-021                             472-021
# 482-017_482-018                     482-017
# 002-001_002-002                     002-001
# 485-004                             485-004
# 491-014                             491-014
# 538-015                             538-015
# 545-003                             545-003
# 587-003                             587-003
# 601-033                             601-033
# 697-015                             697-015
# 697-029                             697-029
# 342-027                             342-027
# 741-002                             741-002
# 741-010                             741-010
# 343-036                             343-036
# 347-004                             347-004
# 779-002                             779-002
# 000-000_35d                             35d
# 393-013_393-014                     393-013
# 394-021_395-001             394-021/395-001
# 854-017                             854-017
# 855-010                             855-010
# 856-004                             856-004
# 858-003                             858-003
# 862-004                             862-004
# 862-006                             862-006
# 864-004                             864-004
# 865-014                             865-014
# 866-003                             866-003
# 872-001                             872-001
# 878-014                             878-014
# 882-012                             882-012
# 884-007                             884-007
# 885-007                             885-007
# 037-175_037-176                     037-175
# 886-008                             886-008
# 421-018                             421-018
# 037-204_037-205                     037-204
# 422-020                             422-020
# 422-033                             422-033
# 423-003                             423-003
# 890-019                             890-019
# 044-158                             044-158
# 428-019                             428-019
# 896-004                             896-004
# 896-005                             896-005
# 428-028                             428-028
# 038-034                             038-034
# 038-037                             038-037
# 896-006                             896-006
# 038-042_038-043                     038-042
# 897-003                             897-003
# 897-004                             897-004
# 897-009                             897-009
# 897-011                             897-011
# 427-005_427-006                     427-005
# 427-010                             427-010
# 898-006                             898-006
# 898-012                             898-012
# 898-023_899-001             898-023/899-001
# 429-003                             429-003
# 900-026                             900-026
# 902-001                             902-001
# 902-002_902-003                     902-002
# 902-009                             902-009
# 429-015                             429-015
# 000-000_37d                             37d
# 429-018                             429-018
# 038-125_038-126                     038-125
# 903-001                             903-001
# 903-006                             903-006
# 903-019                             903-019
# 430-004                             430-004
# 430-022                             430-022
# 038-150                             038-150
# 038-151                             038-151
# 038-154_038-155                     038-154
# 038-156_038-157                     038-156
# 905-008                             905-008
# 431-009                             431-009
# 442-001-069                         442-001
# 039-080_039-081                     039-080
# 039-083                             039-083
#
#                                                      location  \
# exhibit_number
# 472-004_472-005_472-006               White House Oval Office
# 051-001                                          Cabinet Room
# 472-021                               White House Oval Office
# 482-017_482-018                       White House Oval Office
# 002-001_002-002                         White House Telephone
# 485-004                               White House Oval Office
# 491-014                               White House Oval Office
# 538-015                               White House Oval Office
# 545-003                               White House Oval Office
# 587-003                               White House Oval Office
# 601-033                               White House Oval Office
# 697-015                               White House Oval Office
# 697-029                               White House Oval Office
# 342-027                  Old Executive Office Building Office
# 741-002                               White House Oval Office
# 741-010                               White House Oval Office
# 343-036                  Old Executive Office Building Office
# 347-004                  Old Executive Office Building Office
# 779-002                               White House Oval Office
# 000-000_35d                             [Dictabelt Recording]
# 393-013_393-014          Old Executive Office Building Office
# 394-021_395-001          Old Executive Office Building Office
# 854-017                               White House Oval Office
# 855-010                               White House Oval Office
# 856-004                               White House Oval Office
# 858-003                               White House Oval Office
# 862-004                               White House Oval Office
# 862-006                               White House Oval Office
# 864-004                               White House Oval Office
# 865-014                               White House Oval Office
# 866-003                               White House Oval Office
# 872-001                               White House Oval Office
# 878-014                               White House Oval Office
# 882-012                               White House Oval Office
# 884-007                               White House Oval Office
# 885-007                               White House Oval Office
# 037-175_037-176                         White House Telephone
# 886-008                               White House Oval Office
# 421-018                  Old Executive Office Building Office
# 037-204_037-205                         White House Telephone
# 422-020                  Old Executive Office Building Office
# 422-033                  Old Executive Office Building Office
# 423-003                  Old Executive Office Building Office
# 890-019                               White House Oval Office
# 044-158                                 White House Telephone
# 428-019                  Old Executive Office Building Office
# 896-004                               White House Oval Office
# 896-005                               White House Oval Office
# 428-028                  Old Executive Office Building Office
# 038-034                                 White House Telephone
# 038-037                                 White House Telephone
# 896-006                               White House Oval Office
# 038-042_038-043                         White House Telephone
# 897-003                               White House Oval Office
# 897-004                               White House Oval Office
# 897-009                               White House Oval Office
# 897-011                               White House Oval Office
# 427-005_427-006                 Old Executive Office Building
# 427-010                         Old Executive Office Building
# 898-006                               White House Oval Office
# 898-012                               White House Oval Office
# 898-023_899-001                       White House Oval Office
# 429-003                         Old Executive Office Building
# 900-026                               White House Oval Office
# 902-001                               White House Oval Office
# 902-002_902-003                       White House Oval Office
# 902-009                               White House Oval Office
# 429-015                         Old Executive Office Building
# 000-000_37d                             [Dictabelt Recording]
# 429-018                         Old Executive Office Building
# 038-125_038-126                         White House Telephone
# 903-001                               White House Oval Office
# 903-006                               White House Oval Office
# 903-019                               White House Oval Office
# 430-004                         Old Executive Office Building
# 430-022                         Old Executive Office Building
# 038-150                                 White House Telephone
# 038-151                                 White House Telephone
# 038-154_038-155                         White House Telephone
# 038-156_038-157                         White House Telephone
# 905-008                               White House Oval Office
# 431-009                         Old Executive Office Building
# 442-001-069                     Old Executive Office Building
# 039-080_039-081                         White House Telephone
# 039-083                                 White House Telephone
#
#                                                               participants  \
# exhibit_number
# 472-004_472-005_472-006                 [President Nixon, Stephen B. Bull]
# 051-001                   [President Nixon, Leaders of the Dairy Industry]
# 472-021                  [President Nixon, John B. Connally, John D. Eh...
# 482-017_482-018          [President Nixon, John D, Ehrlichman, George P...
# 002-001_002-002                  [President Nixon, Richard G. Kleindienst]
# 485-004                                [President Nixon, John N. Mitchell]
# 491-014                          [President Nixon, H. R. ("Bob") Haldeman]
# 538-015                  [President Nixon, John N. Mitchell, John D. Eh...
# 545-003                  [President Nixon, John D. Ehrlichman, Egil ("B...
# 587-003                  [President Nixon, John N. Mitchell, John D. Eh...
# 601-033                  [President Nixon, John D. Ehrlichman, Stephen ...
# 697-015                          [President Nixon, H. R. ("Bob") Haldeman]
# 697-029                  [President Nixon, H. R. ("Bob") Haldeman, Char...
# 342-027                               [President Nixon, Charles W. Colson]
# 741-002                  [President Nixon, H. R. ("Bob") Haldeman, Rona...
# 741-010                          [President Nixon, H. R. ("Bob") Haldeman]
# 343-036                  [President Nixon, H. R. ("Bob") Haldeman, Rona...
# 347-004                  [President Nixon, John N. Mitchell, H. R. ("Bo...
# 779-002                  [President Nixon,  H. R. ("Bob") Haldeman, Joh...
# 000-000_35d                            [Charles W. Colson, E. Howard Hunt]
# 393-013_393-014                       [President Nixon, Charles W. Colson]
# 394-021_395-001                       [President Nixon, Charles W. Colson]
# 854-017                               [President Nixon, Charles W. Colson]
# 855-010                  [President Nixon, Charles W. Colson, Stephen B...
# 856-004                              [President Nixon, John D. Ehrlichman]
# 858-003                  [President Nixon, John D. Ehrlichman, L. Patri...
# 862-004                  [President Nixon, John D. Ehrlichman, Stephen ...
# 862-006                          [President Nixon, Richard G. Kleindienst]
# 864-004                  [President Nixon, John W, Dean, III, Stephen B...
# 865-014                  [President Nixon, John W, Dean, III, Stephen B...
# 866-003                  [President Nixon, John W. Dean, III, Manolo Sa...
# 872-001                               [President Nixon, John W. Dean, III]
# 878-014                  [President Nixon, H. R. ("Bob") Haldeman, John...
# 882-012                  [President Nixon, John W. Dean, III, H. R. ("B...
# 884-007                          [President Nixon, H. R. ("Bob") Haldeman]
# 885-007                          [President Nixon, H. R. ("Bob") Haldeman]
# 037-175_037-176          [President Nixon, John W. Dean, III, White Hou...
# 886-008                  [President Nixon, John W, Dean, III, H. R. ("B...
# 421-018                  [President Nixon, John W. Dean, III, H. R. ("B...
# 037-204_037-205          [President Nixon, Charles W. Colson, White Hou...
# 422-020                          [President Nixon, H. R. ("Bob") Haldeman]
# 422-033                  [President Nixon, John W. Dean, III, John D. E...
# 423-003                  [President Nixon, H. R. ("Bob") Haldeman, John...
# 890-019                  [President Nixon, Ronald L. Ziegler, John D. E...
# 044-158                               [President Nixon, Charles W. Colson]
# 428-019                  [President Nixon, H. R. ("Bob") Haldeman, John...
# 896-004                  [President Nixon, H. R. ("Bob") Haldeman, John...
# 896-005                  [President Nixon, H. R. ("Bob") Haldeman, John...
# 428-028                  [President Nixon, H. R. ("Bob") Haldeman, John...
# 038-034                          [President Nixon, H. R. ("Bob") Haldeman]
# 038-037                              [President Nixon, John D. Ehrlichman]
# 896-006                  [President Nixon, John D. Ehrlichman, Manolo S...
# 038-042_038-043          [President Nixon, H. R. ("Bob") Haldeman, John...
# 897-003                  [President Nixon, H. R. ("Bob") Haldeman, John...
# 897-004                  [President Nixon, John W. Dean, III, Stephen B...
# 897-009                  [President Nixon, H. R. ("Bob") Haldeman, John...
# 897-011                          [President Nixon, H. R. ("Bob") Haldeman]
# 427-005_427-006          [President Nixon, Ronald L. Ziegler, John D. E...
# 427-010                               [President Nixon, John W. Dean, III]
# 898-006                  [President Nixon, H. R. ("Bob") Haldeman, Rose...
# 898-012                  [President Nixon,  H. R. ("Bob") Haldeman, Joh...
# 898-023_899-001          [President Nixon, H. R. ("Bob") Haldeman, Rona...
# 429-003                  [President Nixon, William P. Rogers, H. R. ("B...
# 900-026                              [President Nixon, John D. Ehrlichman]
# 902-001                  [President Nixon, H. R. ("Bob") Haldeman, John...
# 902-002_902-003                       [President Nixon, Henry E. Petersen]
# 902-009                              [President Nixon, John D. Ehrlichman]
# 429-015                                [President Nixon, Richard A. Moore]
# 000-000_37d                      [John D. Ehrlichman, Herbert W. Kalmbach]
# 429-018                  [President Nixon, John D. Ehrlichman, Manolo S...
# 038-125_038-126          [President Nixon, H. R. ("Bob") Haldeman, Whit...
# 903-001                          [President Nixon, H. R. ("Bob") Haldeman]
# 903-006                          [President Nixon, H. R. ("Bob") Haldeman]
# 903-019                  [President Nixon, H. R. ("Bob") Haldeman, John...
# 430-004                  [President Nixon, H. R. ("Bob") Haldeman, John...
# 430-022                          [President Nixon, H. R. ("Bob") Haldeman]
# 038-150                          [President Nixon, H. R. ("Bob") Haldeman]
# 038-151                              [President Nixon, John D. Ehrlichman]
# 038-154_038-155          [President Nixon, John D. Ehrlichman, White Ho...
# 038-156_038-157          [President Nixon, H. R. ("Bob") Haldeman, Whit...
# 905-008                          [President Nixon, H. R. ("Bob") Haldeman]
# 431-009                  [President Nixon, H. R. ("Bob") Haldeman,  Joh...
# 442-001-069              [President Nixon, John W. Dean, III, Stephen B...
# 039-080_039-081          [President Nixon, H. R. ("Bob") Haldeman, Whit...
# 039-083                          [President Nixon, H. R. ("Bob") Haldeman]
#
#                                     txtdate               cassette_number  \
# exhibit_number
# 472-004_472-005_472-006      March 23, 1971                        [E-25]
# 051-001                      March 23, 1971                  [E-26, E-27]
# 472-021                      March 23, 1971                        [E-28]
# 482-017_482-018              April 19, 1971                        [E-29]
# 002-001_002-002              April 19, 1971                        [E-30]
# 485-004                      April 21, 1971                        [E-31]
# 491-014                         May 5, 1971                        [E-32]
# 538-015                        July 6, 1971                        [E-33]
# 545-003                       July 24, 1971                        [E-34]
# 587-003                     October 8, 1971                        [E-35]
# 601-033                    October 25, 1971                        [E-36]
# 697-015                      March 30, 1972                        [E-37]
# 697-029                      March 30, 1972                        [E-38]
# 342-027                       June 20, 1972                        [E-40]
# 741-002                       June 23, 1972                  [E-41, E-42]
# 741-010                       June 23, 1972                        [E-43]
# 343-036                       June 23, 1972                        [E-44]
# 347-004                       June 30, 1972                        [E-45]
# 779-002                  September 15, 1972                  [E-46, E-47]
# 000-000_35d                         Unknown                        [E-48]
# 393-013_393-014             January 4, 1973                        [E-49]
# 394-021_395-001             January 8, 1973                        [E-51]
# 854-017                   February 13, 1973                        [E-52]
# 855-010                   February 14, 1973                        [E-53]
# 856-004                   February 14, 1973                        [E-54]
# 858-003                   February 16, 1973                        [E-55]
# 862-004                   February 23, 1973                        [E-56]
# 862-006                   February 23, 1973                        [E-57]
# 864-004                   February 27, 1973                        [E-58]
# 865-014                   February 28, 1973                  [E-59, E-60]
# 866-003                       March 1, 1973                        [E-61]
# 872-001                       March 8, 1973                        [E-62]
# 878-014                      March 13, 1973                  [E-63, E-64]
# 882-012                      March 17, 1973                        [E-65]
# 884-007                      March 20, 1973                        [E-66]
# 885-007                      March 20, 1973                        [E-67]
# 037-175_037-176              March 20, 1973                        [E-68]
# 886-008                      March 20, 1973            [E-69, E-70, E-71]
# 421-018                      March 20, 1973                        [E-72]
# 037-204_037-205              March 20, 1973                        [E-73]
# 422-020                      March 22, 1973                  [E-74, E-75]
# 422-033                      March 22, 1973                  [E-76, E-77]
# 423-003                      March 27, 1973            [E-78, E-79, E-80]
# 890-019                      March 30, 1973                        [E-81]
# 044-158                      April 12, 1973                        [E-82]
# 428-019                      April 14, 1973            [E-83, E-84, E-85]
# 896-004                      April 14, 1973                        [E-86]
# 896-005                      April 14, 1973                        [E-87]
# 428-028                      April 14, 1973                  [E-88, E-89]
# 038-034                      April 14, 1973                        [E-90]
# 038-037                      April 14, 1973                        [E-91]
# 896-006                      April 15, 1973                        [E-92]
# 038-042_038-043              April 15, 1973                        [E-93]
# 897-003                      April 16, 1973                        [E-94]
# 897-004                      April 16, 1973                        [E-95]
# 897-009                      April 16, 1973                        [E-96]
# 897-011                      April 16, 1973                        [E-97]
# 427-005_427-006              April 16, 1973                        [E-98]
# 427-010                      April 16, 1973                        [E-99]
# 898-006                      April 17, 1973                       [E-100]
# 898-012                      April 17, 1973         [E-101, E-102, E-103]
# 898-023_899-001              April 17, 1973                       [E-104]
# 429-003                      April 17, 1973                [E-105, E-106]
# 900-026                      April 18, 1973                       [E-107]
# 902-001                      April 19, 1973                       [E-108]
# 902-002_902-003              April 19, 1973                       [E-109]
# 902-009                      April 19, 1973                       [E-110]
# 429-015                      April 19, 1973                [E-111, E-112]
# 000-000_37d                         Unknown                       [E-113]
# 429-018                      April 19, 1973                       [E-114]
# 038-125_038-126              April 19, 1973                       [E-115]
# 903-001                      April 20, 1973                       [E-116]
# 903-006                      April 20, 1973                       [E-117]
# 903-019                      April 20, 1973                       [E-118]
# 430-004                      April 25, 1973  [E-119, E-120, E-121, E-122]
# 430-022                      April 25, 1973                       [E-123]
# 038-150                      April 25, 1973                       [E-124]
# 038-151                      April 25, 1973                       [E-125]
# 038-154_038-155              April 25, 1973                       [E-126]
# 038-156_038-157              April 25, 1973                       [E-127]
# 905-008                      April 26, 1973                [E-128, E-129]
# 431-009                      April 26, 1973  [E-130, E-131, E-135, E-136]
# 442-001-069                    June 4, 1973  [E-137, E-138, E-142, E-143]
# 039-080_039-081                June 4, 1973                       [E-144]
# 039-083                        June 4, 1973                       [E-145]
#
#                         minutes       date
# exhibit_number
# 472-004_472-005_472-006       3 1971-03-23
# 051-001                      49 1971-03-23
# 472-021                      31 1971-03-23
# 482-017_482-018              31 1971-04-19
# 002-001_002-002               1 1971-04-19
# 485-004                       3 1971-04-21
# 491-014                      28 1971-05-05
# 538-015                      19 1971-07-06
# 545-003                      12 1971-07-24
# 587-003                       9 1971-10-08
# 601-033                      26 1971-10-25
# 697-015                      25 1972-03-30
# 697-029                      46 1972-03-30
# 342-027                      21 1972-06-20
# 741-002                      54 1972-06-23
# 741-010                       4 1972-06-23
# 343-036                      23 1972-06-23
# 347-004                       3 1972-06-30
# 779-002                      48 1972-09-15
# 000-000_35d                  18 1972-11-01
# 393-013_393-014              25 1973-01-04
# 394-021_395-001              23 1973-01-08
# 854-017                      12 1973-02-13
# 855-010                      20 1973-02-14
# 856-004                      16 1973-02-14
# 858-003                      29 1973-02-16
# 862-004                      22 1973-02-23
# 862-006                      44 1973-02-23
# 864-004                       3 1973-02-27
# 865-014                      56 1973-02-28
# 866-003                      26 1973-03-01
# 872-001                       4 1973-03-08
# 878-014                      69 1973-03-13
# 882-012                      33 1973-03-17
# 884-007                       4 1973-03-20
# 885-007                      46 1973-03-20
# 037-175_037-176              14 1973-03-20
# 886-008                     111 1973-03-20
# 421-018                      36 1973-03-20
# 037-204_037-205              14 1973-03-20
# 422-020                     106 1973-03-22
# 422-033                      88 1973-03-22
# 423-003                     109 1973-03-27
# 890-019                      16 1973-03-30
# 044-158                      15 1973-04-12
# 428-019                     126 1973-04-14
# 896-004                      47 1973-04-14
# 896-005                      43 1973-04-14
# 428-028                      57 1973-04-14
# 038-034                      12 1973-04-14
# 038-037                      29 1973-04-14
# 896-006                      31 1973-04-15
# 038-042_038-043              18 1973-04-15
# 897-003                      19 1973-04-16
# 897-004                      37 1973-04-16
# 897-009                      12 1973-04-16
# 897-011                      22 1973-04-16
# 427-005_427-006              29 1973-04-16
# 427-010                      19 1973-04-16
# 898-006                      11 1973-04-17
# 898-012                     107 1973-04-17
# 898-023_899-001              43 1973-04-17
# 429-003                      94 1973-04-17
# 900-026                      18 1973-04-18
# 902-001                      34 1973-04-19
# 902-002_902-003              11 1973-04-19
# 902-009                      30 1973-04-19
# 429-015                      71 1973-04-19
# 000-000_37d                  10 1973-04-18
# 429-018                      26 1973-04-19
# 038-125_038-126              15 1973-04-19
# 903-001                      16 1973-04-20
# 903-006                      22 1973-04-20
# 903-019                      17 1973-04-20
# 430-004                     150 1973-04-25
# 430-022                      42 1973-04-25
# 038-150                      17 1973-04-25
# 038-151                       2 1973-04-25
# 038-154_038-155              14 1973-04-25
# 038-156_038-157               8 1973-04-25
# 905-008                      89 1973-04-26
# 431-009                     309 1973-04-26
# 442-001-069                 281 1973-06-04
# 039-080_039-081              15 1973-06-04
# 039-083                       1 1973-06-04

# %% [markdown]
# ### Process Transcript Data

# %% [markdown]
# #### Download transcripts per exhibit

# %%
# collect the pdf file links to the annotated transcripts
pdf_urls = []
for i in all_pdfs:
    txt = str(i.string)
    if "pdf" in txt: # Identify links with 'pdf'
        pdf_urls.append(i['href'])

# %% [markdown]
# #### Extract Text from downloaded PDFs

# %%
### From provided url, writes pdf file into the local directory
def download_file(url):

    # generate a filename to store the pdf in the local directory, based on the URL
    local_pdf_filename = url.split('/')[-1]
    
    # write the pdf file to the local directory, must be written in binary mode ('wb')
    with requests.get(url) as r:
        with open(local_pdf_filename, 'wb') as f:
            f.write(r.content) 
            
    return local_pdf_filename

## Thank you: https://stackoverflow.com/questions/64911851/cant-open-a-pdf-file-using-pdfplumber-open
# requests library and pdfplumber library must be imported

# %%
### From provided local filename, extracts text using pdfplumber
def extractText(local_pdf_filename):

    # extract the text
    with pdfplumber.open(local_pdf_filename) as pdf:
        pages = pdf.pages # stores all pages
        fulltext = []
        pagetext = []
            
        for n in range(len(pages)):
            try:
                pagetext = pages[n].extract_text()
                fulltext.append([pagetext])
            except:
                print("Encountered Error!")
                errorstring = ("error on page"+" "+ str(n+1))
                fulltext.insert(0,errorstring)
                continue
    
    title = local_pdf_filename[:-4]
    
    return title, fulltext

# %%
# Process the files
# store each fulltext dataset in a dictionary identified by the name of the file

## Create a dictionary to store the outputs
text_dict = {}

## Run the function on each transcript pdf
for p in pdf_urls:
    filelist = download_file(p)
    transcript = extractText(filelist)
    print(filelist, len(transcript[1]))

    k = transcript[0] # title - filename
    v = transcript[1] # transcript
    text_dict.update({k:v})
# Out:
# 472-004_472-005_472-006.pdf 4
# 051-001.pdf 32
# 472-021.pdf 43
# 482-017_482-018.pdf 34
# 002-001_002-002.pdf 3
# 485-004.pdf 4
# 491-014.pdf 27
# 538-015.pdf 16
# 545-003.pdf 7
# 587-003.pdf 9
# 601-033.pdf 22
# 697-015.pdf 22
# 697-029.pdf 42
# 342-027.pdf 17
# 741-002.pdf 39
# 741-010.pdf 3
# 343-036.pdf 13
# 347-004.pdf 3
# 779-002.pdf 44
# 000-000_35d.pdf 18
# 393-013_393-014.pdf 18
# 394-021_395-001.pdf 15
# 854-017.pdf 11
# 855-010.pdf 21
# 856-004.pdf 16
# 858-003.pdf 28
# 862-004.pdf 18
# 862-006.pdf 33
# 864-004.pdf 22
# 865-014.pdf 49
# 866-003.pdf 21
# 872-001.pdf 2
# 878-014.pdf 77
# 882-012.pdf 27
# 884-007.pdf 4
# 885-007.pdf 27
# 037-175_037-176.pdf 18
# 886-008.pdf 127
# 421-018.pdf 39
# 037-204_037-205.pdf 12
# 422-020.pdf 59
# 422-033.pdf 105
# 423-003.pdf 85
# 890-019.pdf 13
# 044-158.pdf 18
# 428-019.pdf 99
# 896-004.pdf 13
# 896-005.pdf 57
# 428-028.pdf 52
# 038-034.pdf 12
# 038-037.pdf 30
# 896-006.pdf 22
# 038-042_038-043.pdf 22
# 897-003.pdf 16
# 897-004.pdf 56
# 897-009.pdf 12
# 897-011.pdf 23
# 427-005_427-006.pdf 24
# 427-010.pdf 27
# 898-006.pdf 8
# 898-012.pdf 97
# 898-023_899-001.pdf 29
# 429-003.pdf 66
# 900-026.pdf 18
# 902-001.pdf 28
# 902-002_902-003.pdf 8
# 902-009.pdf 21
# 429-015.pdf 70
# 000-000_37d.pdf 12
# 429-018.pdf 25
# 038-125_038-126.pdf 16
# 903-001.pdf 16
# 903-006.pdf 16
# 903-019.pdf 17
# 430-004.pdf 115
# 430-022.pdf 37
# 038-150.pdf 18
# 038-151.pdf 4
# 038-154_038-155.pdf 14
# 038-156_038-157.pdf 9
# 905-008.pdf 75
# 431-009.pdf 187
# 442-001-069.pdf 170
# 039-080_039-081.pdf 20
# 039-083.pdf 2

# %%
len(text_dict)
# Out:
# 85

# %%
# Place the transcripts in a dataframe
df_text = pd.DataFrame([text_dict]).T
df_text.rename(columns = {0:'full_extracted_text'}, 
            inplace = True)
df_text
# Out:
#                                                        full_extracted_text
# 472-004_472-005_472-006  [[TRANSCRIPT PREPARED BY THE IMPEACHMENT INQUI...
# 051-001                  [[TRANSCRIPT PREPARED BY THE IMPEACHMENT INQUI...
# 472-021                  [[MEETING AMONG PRESIDENT RICHARD M. NIXON, JO...
# 482-017_482-018          [[TRANSCRIPT PREPARED BY THE IMPEACHMENT INQUI...
# 002-001_002-002          [[TRANSCRIPT PREPARED BY THE IMPEACHMENT INQUI...
# ...                                                                    ...
# 905-008                  [[TRANSCRIPT OF A MEETING BETWEEN THE\nPRESIDE...
# 431-009                  [[TRANSCRIPT OF A RECORDING OF A MEETING AMONG...
# 442-001-069              [[***   DRAFT ***\nTRANSCRIPT PREPARED BY THE ...
# 039-080_039-081          [[TRANSCRIPT OF A RECORDING OF A TELEPHONE\nCO...
# 039-083                  [[TRANSCRIPT OF A TELEPHONE CONVERSATION\nBETW...
#
# [85 rows x 1 columns]

# %% [markdown]
# ### Create the df_all dataframe containing all relevant metadata and transcript data

# %%
# Join the text and meta DataFrames

# check shapes
print("before: ",df_meta.shape, '\n\t', df_text.shape)

# merge the DFs
df_all = pd.merge(df_text, df_meta, left_index=True, right_index=True)

# verify shape
print("after:  ",df_all.shape)

df_all.head()
# Out:
# before:  (85, 8)
# 	 (85, 1)
# after:   (85, 9)
#                                                        full_extracted_text  \
# 472-004_472-005_472-006  [[TRANSCRIPT PREPARED BY THE IMPEACHMENT INQUI...
# 051-001                  [[TRANSCRIPT PREPARED BY THE IMPEACHMENT INQUI...
# 472-021                  [[MEETING AMONG PRESIDENT RICHARD M. NIXON, JO...
# 482-017_482-018          [[TRANSCRIPT PREPARED BY THE IMPEACHMENT INQUI...
# 002-001_002-002          [[TRANSCRIPT PREPARED BY THE IMPEACHMENT INQUI...
#
#                                         cassette_number_/_minutes  \
# 472-004_472-005_472-006                        E - 25 (3 minutes)
# 051-001                  E - 26 (49 minutes)  [Concludes on E-27]
# 472-021                                       E - 28 (31 minutes)
# 482-017_482-018                               E - 29 (31 minutes)
# 002-001_002-002                                 E - 30 (1 minute)
#
#                         conversation_number                 location  \
# 472-004_472-005_472-006             472-004  White House Oval Office
# 051-001                             051-001             Cabinet Room
# 472-021                             472-021  White House Oval Office
# 482-017_482-018                     482-017  White House Oval Office
# 002-001_002-002                     002-001    White House Telephone
#
#                                                               participants  \
# 472-004_472-005_472-006                 [President Nixon, Stephen B. Bull]
# 051-001                   [President Nixon, Leaders of the Dairy Industry]
# 472-021                  [President Nixon, John B. Connally, John D. Eh...
# 482-017_482-018          [President Nixon, John D, Ehrlichman, George P...
# 002-001_002-002                  [President Nixon, Richard G. Kleindienst]
#
#                                 txtdate cassette_number minutes       date
# 472-004_472-005_472-006  March 23, 1971          [E-25]       3 1971-03-23
# 051-001                  March 23, 1971    [E-26, E-27]      49 1971-03-23
# 472-021                  March 23, 1971          [E-28]      31 1971-03-23
# 482-017_482-018          April 19, 1971          [E-29]      31 1971-04-19
# 002-001_002-002          April 19, 1971          [E-30]       1 1971-04-19

# %%
# Manage Exception
# Exhibit 485-004 has no header and the speaker names are not listed and do not contain ':'
# Exhibit 872-001, 697-015, 545-003 speaker names are not listed and do not contain ':'
# remove these anomalies

df_all.drop(['485-004','872-001','697-015','545-003'], axis=0, inplace=True)

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 81 entries, 472-004_472-005_472-006 to 039-083
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   full_extracted_text        81 non-null     object
#  1   cassette_number_/_minutes  81 non-null     object
#  2   conversation_number        81 non-null     object
#  3   location                   81 non-null     object
#  4   participants               81 non-null     object
#  5   txtdate                    81 non-null     object
#  6   cassette_number            81 non-null     object
#  7   minutes                    81 non-null     object
#  8   date                       81 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), object(8)
# memory usage: 6.3+ KB

# %% [markdown]
# ## Clean Data

# %% [markdown]
# ### Parse text to isolate speech and metadata within the documents

# %%
def flatten(line):
    out = []
    for item in line:
        if isinstance(item, (list, tuple)):
            out.extend(flatten(item))
        else:
            out.append(item)
    return out

# copied from - ref: http://rightfootin.blogspot.com/2006/09/more-on-python-flatten.html

# %%
# Flatten lists
flat_list = df_all.iloc[:,0].apply(lambda x: flatten(x))

# Then flatten text within listas
flat_text = flat_list.apply(lambda x: " ".join(map(str, x)))

df_all["flattened"] = flat_list.apply(lambda x: " ".join(map(str, x)))
#ref: https://stackoverflow.com/questions/12453580/how-to-concatenate-items-in-a-list-to-a-single-string

# %%
# functions for initial grooming

# prints all text contained in () for visual examination prior to removing
def examine_drops(text):
    regex = re.compile(".*?[\[\(](.*?)[\]\)]") # brackets are used instead of parentheses most of the time
    result = re.findall(regex, text)
    return(result)

# removes new line characters and all () including text
def transcript_initialgroom(text):
    #text = re.sub(r"\n", " ", text)
    text = re.sub(r"\s", " ", text)
    text = re.sub(r'\\\\',"",text)
    text = re.sub(r'\\',"",text)
    text = re.sub("[\[\(](.*?)[\]\)]", "", text) #updated with new drops pattern
    return(text)

# drops speakers and replaces with ""
def drop_speakers(text):
    #text = re.sub(r'\b[A-Z]{2,}\b:', "", text) #@MISHA - some of these have camelcase names
    text = re.sub(r'([A-Z][A-Za-z]+\b:)', "", text) #account for upper and camelcase names followed by colon
    return(text)

def drop_repeating(text):
    text = re.sub(r'\b(?:JANUARY|FEBRUARY|MARCH|APRIL|MAY|JUNE|JULY|AUGUST|SEPTEMBER|OCTOBER|NOVEMBER|DECEMBER)\b.*(?!/n)', "", text)
#    text = re.sub(r'\b(?:APRIL|JUNE|SEPTEMBER)\b.*(?!/n)', "\nFOUND A FREAKING MATCH\n", text)
    return(text)

# extracts speech header, and splits into two panda series objects
def extract_speechheader(exhibit_speech):
    """Attempts the most conservative pattern of uppercase NAME: followed by a word with lowercase.
       Then, requires an uppercase NAME:, and finally allows a camelcase Name:
       If these fail, no header will be defined (span ends at 0)"""
    patt1 = r'(\b[A-Z]{2,}\b:\s+(..[a-z]|.[a-z]))' # the NAME: is uppercase and followed by a word with lowercase letters
    patt2 = r'(\b[A-Z]{2,}\b:)' # the NAME: is uppercase
    patt3 = r'([A-Z][A-Za-z]+\b:)' # the first colon following any set of letters
    if re.search(patt1, exhibit_speech)!=None: patt=patt1
    elif re.search(patt2, exhibit_speech)!=None: patt = patt2
    elif re.search(patt3, exhibit_speech)!=None: patt = patt3
    try:
        headerend = re.search(patt, exhibit_speech)[0]
        headerendspan = re.search(patt, exhibit_speech).span()[0]
    except: headerend = headerendspan = 0
    header = exhibit_speech[:headerendspan]
    speech = exhibit_speech[headerendspan:]
    return pd.Series([header, speech])

# %%
# extracts and returns start and end time from the speech header
def timehdr(text):
    """finds and calculates the FROM-TO times in the text, assuming from is first and to is last"""
    patt = re.compile(r'([0-9]+:\w\w[\sAaPp])') #[^/]+$ brings the rest of the line; +\b brings the rest of the word; ref Joey https://stackoverflow.com/questions/11347868/regex-to-get-last-word-from-sentence-of-words-separated-by
    iter = patt.finditer(text)
    wrds = [i for m in iter for i in m.span()]
    try:
        # Find the start and end times in the text
        s,e = min(wrds), max(wrds)+3
        times = text[s:e].replace(".","").replace("*","").replace("-"," ").strip().upper().split()
        s_time = re.sub("[A-Z]","1",times[0]) # assumes start time is first in the list; any letters will be replaced with 1
        e_merid = times[-1][0]+"M" # assumes AM or PM are the final element in the list
        e_time = re.sub("[A-Z]","1",times[-2]) # assumes end time is second to last in the list; any letters will be replaced with 1

        # determine AM or PM
        st = int(s_time.split(":")[0]) # find the hour of the start time
        et = int(e_time.split(":")[0]) # find the hour of the end time
        if st==12: s_merid=e_merid
        elif st>et or et==12:
            if e_merid=="PM": s_merid="AM"
            elif st>et and e_merid=="AM": s_merid="PM"
        else: s_merid=e_merid
        times = [s_time+s_merid,e_time+e_merid]
        
        # calculate date-time
        sdtime = pd.to_timedelta(str(datetime.strptime(times[0], '%I:%M%p').time())) # start time
        edtime = pd.to_timedelta(str(datetime.strptime(times[1], '%I:%M%p').time())) # end time
    except: sdtime = edtime = pd.to_timedelta('00:00:00')
    diff = edtime-sdtime # time difference between start/end
    return sdtime, edtime, diff

# %%
# Process Transcript parsing and grooming functions
# examine words in paragraphs
df_all['dropped'] = df_all['flattened'].apply(lambda row: examine_drops(row))

# apply initial grooming to flattened dataset (removes new line characters and all () including text
df_all[['speech_header', 'speech']] = df_all['flattened'].apply(lambda row: extract_speechheader(row))

# remove repeating row from flattened dataset
df_all['speech_flat_norepeat'] = df_all['speech'].apply(lambda row: drop_repeating(row))

# apply initial grooming to flattened dataset (removes new line characters and all () including text
df_all['speech_groomed'] = df_all['speech_flat_norepeat'].apply(lambda row: transcript_initialgroom(row))

# apply initial grooming to the speech header
df_all['speech_header'] = df_all['speech_header'].apply(
    lambda x: transcript_initialgroom(x))

# apply drop speakers to groomed speech
df_all['speech_final'] = df_all['speech_groomed'].apply(lambda row: drop_speakers(row))

# %%
# run the function to get time from speech header data
dfsh = df_all['speech_header'].copy()
timer = dfsh.apply(lambda row: timehdr(row))
dfsh = pd.DataFrame([[a,b,c] for a,b,c in timer.values], 
                    columns = ['start_time','end_time','time_diff'], index = timer.index)

# # add start, end, diff columns to df_all
df_all = pd.concat([df_all,dfsh], axis=1)
df_all['start_dtime'] = df_all['date']+df_all['start_time']
df_all['end_dtime'] = df_all['date']+df_all['end_time']

# ref: jezrael https://stackoverflow.com/questions/57847521/summing-two-datetime-columns
# ref: cs95 https://stackoverflow.com/questions/53402584/how-to-convert-a-series-of-tuples-into-a-pandas-dataframe

# %% [markdown]
# ### Finalize the dataframe columns

# %%
# Select df_all columns to carry forward
df_all = df_all[['conversation_number','cassette_number'
                ,'location','participants','minutes','txtdate',
                'date','start_dtime','end_dtime','time_diff','full_extracted_text',
                'dropped', 'speech_header','speech_flat_norepeat','speech_final']]

# %%
display(df_all.info())
pd.options.display.max_rows = 1000
display(df_all)
pd.reset_option("display.max_rows")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 81 entries, 472-004_472-005_472-006 to 039-083
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   conversation_number   81 non-null     object
#  1   cassette_number       81 non-null     object
#  2   location              81 non-null     object
#  3   participants          81 non-null     object
#  4   minutes               81 non-null     object
#  5   txtdate               81 non-null     object
#  6   date                  81 non-null     datetime64[ns]
#  7   start_dtime           81 non-null     datetime64[ns]
#  8   end_dtime             81 non-null     datetime64[ns]
#  9   time_diff             81 non-null     timedelta64[ns]
#  10  full_extracted_text   81 non-null     object
#  11  dropped               81 non-null     object
#  12  speech_header         81 non-null     object
#  13  speech_flat_norepeat  81 non-null     object
#  14  speech_final          81 non-null     object
# dtypes: datetime64[ns](3), object(11), timedelta64[ns](1)
# memory usage: 10.1+ KB
# None
#                         conversation_number               cassette_number  \
# 472-004_472-005_472-006             472-004                        [E-25]
# 051-001                             051-001                  [E-26, E-27]
# 472-021                             472-021                        [E-28]
# 482-017_482-018                     482-017                        [E-29]
# 002-001_002-002                     002-001                        [E-30]
# 491-014                             491-014                        [E-32]
# 538-015                             538-015                        [E-33]
# 587-003                             587-003                        [E-35]
# 601-033                             601-033                        [E-36]
# 697-029                             697-029                        [E-38]
# 342-027                             342-027                        [E-40]
# 741-002                             741-002                  [E-41, E-42]
# 741-010                             741-010                        [E-43]
# 343-036                             343-036                        [E-44]
# 347-004                             347-004                        [E-45]
# 779-002                             779-002                  [E-46, E-47]
# 000-000_35d                             35d                        [E-48]
# 393-013_393-014                     393-013                        [E-49]
# 394-021_395-001             394-021/395-001                        [E-51]
# 854-017                             854-017                        [E-52]
# 855-010                             855-010                        [E-53]
# 856-004                             856-004                        [E-54]
# 858-003                             858-003                        [E-55]
# 862-004                             862-004                        [E-56]
# 862-006                             862-006                        [E-57]
# 864-004                             864-004                        [E-58]
# 865-014                             865-014                  [E-59, E-60]
# 866-003                             866-003                        [E-61]
# 878-014                             878-014                  [E-63, E-64]
# 882-012                             882-012                        [E-65]
# 884-007                             884-007                        [E-66]
# 885-007                             885-007                        [E-67]
# 037-175_037-176                     037-175                        [E-68]
# 886-008                             886-008            [E-69, E-70, E-71]
# 421-018                             421-018                        [E-72]
# 037-204_037-205                     037-204                        [E-73]
# 422-020                             422-020                  [E-74, E-75]
# 422-033                             422-033                  [E-76, E-77]
# 423-003                             423-003            [E-78, E-79, E-80]
# 890-019                             890-019                        [E-81]
# 044-158                             044-158                        [E-82]
# 428-019                             428-019            [E-83, E-84, E-85]
# 896-004                             896-004                        [E-86]
# 896-005                             896-005                        [E-87]
# 428-028                             428-028                  [E-88, E-89]
# 038-034                             038-034                        [E-90]
# 038-037                             038-037                        [E-91]
# 896-006                             896-006                        [E-92]
# 038-042_038-043                     038-042                        [E-93]
# 897-003                             897-003                        [E-94]
# 897-004                             897-004                        [E-95]
# 897-009                             897-009                        [E-96]
# 897-011                             897-011                        [E-97]
# 427-005_427-006                     427-005                        [E-98]
# 427-010                             427-010                        [E-99]
# 898-006                             898-006                       [E-100]
# 898-012                             898-012         [E-101, E-102, E-103]
# 898-023_899-001             898-023/899-001                       [E-104]
# 429-003                             429-003                [E-105, E-106]
# 900-026                             900-026                       [E-107]
# 902-001                             902-001                       [E-108]
# 902-002_902-003                     902-002                       [E-109]
# 902-009                             902-009                       [E-110]
# 429-015                             429-015                [E-111, E-112]
# 000-000_37d                             37d                       [E-113]
# 429-018                             429-018                       [E-114]
# 038-125_038-126                     038-125                       [E-115]
# 903-001                             903-001                       [E-116]
# 903-006                             903-006                       [E-117]
# 903-019                             903-019                       [E-118]
# 430-004                             430-004  [E-119, E-120, E-121, E-122]
# 430-022                             430-022                       [E-123]
# 038-150                             038-150                       [E-124]
# 038-151                             038-151                       [E-125]
# 038-154_038-155                     038-154                       [E-126]
# 038-156_038-157                     038-156                       [E-127]
# 905-008                             905-008                [E-128, E-129]
# 431-009                             431-009  [E-130, E-131, E-135, E-136]
# 442-001-069                         442-001  [E-137, E-138, E-142, E-143]
# 039-080_039-081                     039-080                       [E-144]
# 039-083                             039-083                       [E-145]
#
#                                                      location  \
# 472-004_472-005_472-006               White House Oval Office
# 051-001                                          Cabinet Room
# 472-021                               White House Oval Office
# 482-017_482-018                       White House Oval Office
# 002-001_002-002                         White House Telephone
# 491-014                               White House Oval Office
# 538-015                               White House Oval Office
# 587-003                               White House Oval Office
# 601-033                               White House Oval Office
# 697-029                               White House Oval Office
# 342-027                  Old Executive Office Building Office
# 741-002                               White House Oval Office
# 741-010                               White House Oval Office
# 343-036                  Old Executive Office Building Office
# 347-004                  Old Executive Office Building Office
# 779-002                               White House Oval Office
# 000-000_35d                             [Dictabelt Recording]
# 393-013_393-014          Old Executive Office Building Office
# 394-021_395-001          Old Executive Office Building Office
# 854-017                               White House Oval Office
# 855-010                               White House Oval Office
# 856-004                               White House Oval Office
# 858-003                               White House Oval Office
# 862-004                               White House Oval Office
# 862-006                               White House Oval Office
# 864-004                               White House Oval Office
# 865-014                               White House Oval Office
# 866-003                               White House Oval Office
# 878-014                               White House Oval Office
# 882-012                               White House Oval Office
# 884-007                               White House Oval Office
# 885-007                               White House Oval Office
# 037-175_037-176                         White House Telephone
# 886-008                               White House Oval Office
# 421-018                  Old Executive Office Building Office
# 037-204_037-205                         White House Telephone
# 422-020                  Old Executive Office Building Office
# 422-033                  Old Executive Office Building Office
# 423-003                  Old Executive Office Building Office
# 890-019                               White House Oval Office
# 044-158                                 White House Telephone
# 428-019                  Old Executive Office Building Office
# 896-004                               White House Oval Office
# 896-005                               White House Oval Office
# 428-028                  Old Executive Office Building Office
# 038-034                                 White House Telephone
# 038-037                                 White House Telephone
# 896-006                               White House Oval Office
# 038-042_038-043                         White House Telephone
# 897-003                               White House Oval Office
# 897-004                               White House Oval Office
# 897-009                               White House Oval Office
# 897-011                               White House Oval Office
# 427-005_427-006                 Old Executive Office Building
# 427-010                         Old Executive Office Building
# 898-006                               White House Oval Office
# 898-012                               White House Oval Office
# 898-023_899-001                       White House Oval Office
# 429-003                         Old Executive Office Building
# 900-026                               White House Oval Office
# 902-001                               White House Oval Office
# 902-002_902-003                       White House Oval Office
# 902-009                               White House Oval Office
# 429-015                         Old Executive Office Building
# 000-000_37d                             [Dictabelt Recording]
# 429-018                         Old Executive Office Building
# 038-125_038-126                         White House Telephone
# 903-001                               White House Oval Office
# 903-006                               White House Oval Office
# 903-019                               White House Oval Office
# 430-004                         Old Executive Office Building
# 430-022                         Old Executive Office Building
# 038-150                                 White House Telephone
# 038-151                                 White House Telephone
# 038-154_038-155                         White House Telephone
# 038-156_038-157                         White House Telephone
# 905-008                               White House Oval Office
# 431-009                         Old Executive Office Building
# 442-001-069                     Old Executive Office Building
# 039-080_039-081                         White House Telephone
# 039-083                                 White House Telephone
#
#                                                               participants  \
# 472-004_472-005_472-006                 [President Nixon, Stephen B. Bull]
# 051-001                   [President Nixon, Leaders of the Dairy Industry]
# 472-021                  [President Nixon, John B. Connally, John D. Eh...
# 482-017_482-018          [President Nixon, John D, Ehrlichman, George P...
# 002-001_002-002                  [President Nixon, Richard G. Kleindienst]
# 491-014                          [President Nixon, H. R. ("Bob") Haldeman]
# 538-015                  [President Nixon, John N. Mitchell, John D. Eh...
# 587-003                  [President Nixon, John N. Mitchell, John D. Eh...
# 601-033                  [President Nixon, John D. Ehrlichman, Stephen ...
# 697-029                  [President Nixon, H. R. ("Bob") Haldeman, Char...
# 342-027                               [President Nixon, Charles W. Colson]
# 741-002                  [President Nixon, H. R. ("Bob") Haldeman, Rona...
# 741-010                          [President Nixon, H. R. ("Bob") Haldeman]
# 343-036                  [President Nixon, H. R. ("Bob") Haldeman, Rona...
# 347-004                  [President Nixon, John N. Mitchell, H. R. ("Bo...
# 779-002                  [President Nixon,  H. R. ("Bob") Haldeman, Joh...
# 000-000_35d                            [Charles W. Colson, E. Howard Hunt]
# 393-013_393-014                       [President Nixon, Charles W. Colson]
# 394-021_395-001                       [President Nixon, Charles W. Colson]
# 854-017                               [President Nixon, Charles W. Colson]
# 855-010                  [President Nixon, Charles W. Colson, Stephen B...
# 856-004                              [President Nixon, John D. Ehrlichman]
# 858-003                  [President Nixon, John D. Ehrlichman, L. Patri...
# 862-004                  [President Nixon, John D. Ehrlichman, Stephen ...
# 862-006                          [President Nixon, Richard G. Kleindienst]
# 864-004                  [President Nixon, John W, Dean, III, Stephen B...
# 865-014                  [President Nixon, John W, Dean, III, Stephen B...
# 866-003                  [President Nixon, John W. Dean, III, Manolo Sa...
# 878-014                  [President Nixon, H. R. ("Bob") Haldeman, John...
# 882-012                  [President Nixon, John W. Dean, III, H. R. ("B...
# 884-007                          [President Nixon, H. R. ("Bob") Haldeman]
# 885-007                          [President Nixon, H. R. ("Bob") Haldeman]
# 037-175_037-176          [President Nixon, John W. Dean, III, White Hou...
# 886-008                  [President Nixon, John W, Dean, III, H. R. ("B...
# 421-018                  [President Nixon, John W. Dean, III, H. R. ("B...
# 037-204_037-205          [President Nixon, Charles W. Colson, White Hou...
# 422-020                          [President Nixon, H. R. ("Bob") Haldeman]
# 422-033                  [President Nixon, John W. Dean, III, John D. E...
# 423-003                  [President Nixon, H. R. ("Bob") Haldeman, John...
# 890-019                  [President Nixon, Ronald L. Ziegler, John D. E...
# 044-158                               [President Nixon, Charles W. Colson]
# 428-019                  [President Nixon, H. R. ("Bob") Haldeman, John...
# 896-004                  [President Nixon, H. R. ("Bob") Haldeman, John...
# 896-005                  [President Nixon, H. R. ("Bob") Haldeman, John...
# 428-028                  [President Nixon, H. R. ("Bob") Haldeman, John...
# 038-034                          [President Nixon, H. R. ("Bob") Haldeman]
# 038-037                              [President Nixon, John D. Ehrlichman]
# 896-006                  [President Nixon, John D. Ehrlichman, Manolo S...
# 038-042_038-043          [President Nixon, H. R. ("Bob") Haldeman, John...
# 897-003                  [President Nixon, H. R. ("Bob") Haldeman, John...
# 897-004                  [President Nixon, John W. Dean, III, Stephen B...
# 897-009                  [President Nixon, H. R. ("Bob") Haldeman, John...
# 897-011                          [President Nixon, H. R. ("Bob") Haldeman]
# 427-005_427-006          [President Nixon, Ronald L. Ziegler, John D. E...
# 427-010                               [President Nixon, John W. Dean, III]
# 898-006                  [President Nixon, H. R. ("Bob") Haldeman, Rose...
# 898-012                  [President Nixon,  H. R. ("Bob") Haldeman, Joh...
# 898-023_899-001          [President Nixon, H. R. ("Bob") Haldeman, Rona...
# 429-003                  [President Nixon, William P. Rogers, H. R. ("B...
# 900-026                              [President Nixon, John D. Ehrlichman]
# 902-001                  [President Nixon, H. R. ("Bob") Haldeman, John...
# 902-002_902-003                       [President Nixon, Henry E. Petersen]
# 902-009                              [President Nixon, John D. Ehrlichman]
# 429-015                                [President Nixon, Richard A. Moore]
# 000-000_37d                      [John D. Ehrlichman, Herbert W. Kalmbach]
# 429-018                  [President Nixon, John D. Ehrlichman, Manolo S...
# 038-125_038-126          [President Nixon, H. R. ("Bob") Haldeman, Whit...
# 903-001                          [President Nixon, H. R. ("Bob") Haldeman]
# 903-006                          [President Nixon, H. R. ("Bob") Haldeman]
# 903-019                  [President Nixon, H. R. ("Bob") Haldeman, John...
# 430-004                  [President Nixon, H. R. ("Bob") Haldeman, John...
# 430-022                          [President Nixon, H. R. ("Bob") Haldeman]
# 038-150                          [President Nixon, H. R. ("Bob") Haldeman]
# 038-151                              [President Nixon, John D. Ehrlichman]
# 038-154_038-155          [President Nixon, John D. Ehrlichman, White Ho...
# 038-156_038-157          [President Nixon, H. R. ("Bob") Haldeman, Whit...
# 905-008                          [President Nixon, H. R. ("Bob") Haldeman]
# 431-009                  [President Nixon, H. R. ("Bob") Haldeman,  Joh...
# 442-001-069              [President Nixon, John W. Dean, III, Stephen B...
# 039-080_039-081          [President Nixon, H. R. ("Bob") Haldeman, Whit...
# 039-083                          [President Nixon, H. R. ("Bob") Haldeman]
#
#                         minutes             txtdate       date  \
# 472-004_472-005_472-006       3      March 23, 1971 1971-03-23
# 051-001                      49      March 23, 1971 1971-03-23
# 472-021                      31      March 23, 1971 1971-03-23
# 482-017_482-018              31      April 19, 1971 1971-04-19
# 002-001_002-002               1      April 19, 1971 1971-04-19
# 491-014                      28         May 5, 1971 1971-05-05
# 538-015                      19        July 6, 1971 1971-07-06
# 587-003                       9     October 8, 1971 1971-10-08
# 601-033                      26    October 25, 1971 1971-10-25
# 697-029                      46      March 30, 1972 1972-03-30
# 342-027                      21       June 20, 1972 1972-06-20
# 741-002                      54       June 23, 1972 1972-06-23
# 741-010                       4       June 23, 1972 1972-06-23
# 343-036                      23       June 23, 1972 1972-06-23
# 347-004                       3       June 30, 1972 1972-06-30
# 779-002                      48  September 15, 1972 1972-09-15
# 000-000_35d                  18             Unknown 1972-11-01
# 393-013_393-014              25     January 4, 1973 1973-01-04
# 394-021_395-001              23     January 8, 1973 1973-01-08
# 854-017                      12   February 13, 1973 1973-02-13
# 855-010                      20   February 14, 1973 1973-02-14
# 856-004                      16   February 14, 1973 1973-02-14
# 858-003                      29   February 16, 1973 1973-02-16
# 862-004                      22   February 23, 1973 1973-02-23
# 862-006                      44   February 23, 1973 1973-02-23
# 864-004                       3   February 27, 1973 1973-02-27
# 865-014                      56   February 28, 1973 1973-02-28
# 866-003                      26       March 1, 1973 1973-03-01
# 878-014                      69      March 13, 1973 1973-03-13
# 882-012                      33      March 17, 1973 1973-03-17
# 884-007                       4      March 20, 1973 1973-03-20
# 885-007                      46      March 20, 1973 1973-03-20
# 037-175_037-176              14      March 20, 1973 1973-03-20
# 886-008                     111      March 20, 1973 1973-03-20
# 421-018                      36      March 20, 1973 1973-03-20
# 037-204_037-205              14      March 20, 1973 1973-03-20
# 422-020                     106      March 22, 1973 1973-03-22
# 422-033                      88      March 22, 1973 1973-03-22
# 423-003                     109      March 27, 1973 1973-03-27
# 890-019                      16      March 30, 1973 1973-03-30
# 044-158                      15      April 12, 1973 1973-04-12
# 428-019                     126      April 14, 1973 1973-04-14
# 896-004                      47      April 14, 1973 1973-04-14
# 896-005                      43      April 14, 1973 1973-04-14
# 428-028                      57      April 14, 1973 1973-04-14
# 038-034                      12      April 14, 1973 1973-04-14
# 038-037                      29      April 14, 1973 1973-04-14
# 896-006                      31      April 15, 1973 1973-04-15
# 038-042_038-043              18      April 15, 1973 1973-04-15
# 897-003                      19      April 16, 1973 1973-04-16
# 897-004                      37      April 16, 1973 1973-04-16
# 897-009                      12      April 16, 1973 1973-04-16
# 897-011                      22      April 16, 1973 1973-04-16
# 427-005_427-006              29      April 16, 1973 1973-04-16
# 427-010                      19      April 16, 1973 1973-04-16
# 898-006                      11      April 17, 1973 1973-04-17
# 898-012                     107      April 17, 1973 1973-04-17
# 898-023_899-001              43      April 17, 1973 1973-04-17
# 429-003                      94      April 17, 1973 1973-04-17
# 900-026                      18      April 18, 1973 1973-04-18
# 902-001                      34      April 19, 1973 1973-04-19
# 902-002_902-003              11      April 19, 1973 1973-04-19
# 902-009                      30      April 19, 1973 1973-04-19
# 429-015                      71      April 19, 1973 1973-04-19
# 000-000_37d                  10             Unknown 1973-04-18
# 429-018                      26      April 19, 1973 1973-04-19
# 038-125_038-126              15      April 19, 1973 1973-04-19
# 903-001                      16      April 20, 1973 1973-04-20
# 903-006                      22      April 20, 1973 1973-04-20
# 903-019                      17      April 20, 1973 1973-04-20
# 430-004                     150      April 25, 1973 1973-04-25
# 430-022                      42      April 25, 1973 1973-04-25
# 038-150                      17      April 25, 1973 1973-04-25
# 038-151                       2      April 25, 1973 1973-04-25
# 038-154_038-155              14      April 25, 1973 1973-04-25
# 038-156_038-157               8      April 25, 1973 1973-04-25
# 905-008                      89      April 26, 1973 1973-04-26
# 431-009                     309      April 26, 1973 1973-04-26
# 442-001-069                 281        June 4, 1973 1973-06-04
# 039-080_039-081              15        June 4, 1973 1973-06-04
# 039-083                       1        June 4, 1973 1973-06-04
#
#                                 start_dtime           end_dtime  \
# 472-004_472-005_472-006 1971-03-23 10:16:00 1971-03-23 10:19:00
# 051-001                 1971-03-23 10:35:00 1971-03-23 11:25:00
# 472-021                 1971-03-23 17:05:00 1971-03-23 17:38:00
# 482-017_482-018         1971-04-19 15:03:00 1971-04-19 15:34:00
# 002-001_002-002         1971-04-19 15:04:00 1971-04-19 15:09:00
# 491-014                 1971-05-05 09:55:00 1971-05-05 09:55:00
# 538-015                 1971-07-06 00:00:00 1971-07-06 00:00:00
# 587-003                 1971-10-08 10:04:00 1971-10-08 10:46:00
# 601-033                 1971-10-25 12:35:00 1971-10-25 14:05:00
# 697-029                 1972-03-30 13:30:00 1972-03-30 14:30:00
# 342-027                 1972-06-20 14:20:00 1972-06-20 15:30:00
# 741-002                 1972-06-23 10:04:00 1972-06-23 11:39:00
# 741-010                 1972-06-23 13:04:00 1972-06-23 13:13:00
# 343-036                 1972-06-23 14:20:00 1972-06-23 14:45:00
# 347-004                 1972-06-30 12:55:00 1972-06-30 14:10:00
# 779-002                 1972-09-15 17:24:00 1972-09-15 18:17:00
# 000-000_35d             1972-11-01 00:00:00 1972-11-01 00:00:00
# 393-013_393-014         1973-01-04 12:02:00 1973-01-04 13:02:00
# 394-021_395-001         1973-01-08 16:05:00 1973-01-08 17:34:00
# 854-017                 1973-02-13 09:48:00 1973-02-13 10:52:00
# 855-010                 1973-02-14 22:13:00 1973-02-14 22:49:00
# 856-004                 1973-02-14 17:34:00 1973-02-14 18:00:00
# 858-003                 1973-02-16 09:08:00 1973-02-16 09:39:00
# 862-004                 1973-02-23 09:35:00 1973-02-23 10:05:00
# 862-006                 1973-02-23 10:08:00 1973-02-23 10:52:00
# 864-004                 1973-02-27 15:55:00 1973-02-27 16:20:00
# 865-014                 1973-02-28 09:12:00 1973-02-28 10:23:00
# 866-003                 1973-03-01 09:18:00 1973-03-01 09:45:00
# 878-014                 1973-03-13 12:42:00 1973-03-13 14:00:00
# 882-012                 1973-03-17 13:25:00 1973-03-17 14:10:00
# 884-007                 1973-03-20 10:47:00 1973-03-20 12:10:00
# 885-007                 1973-03-20 18:00:00 1973-03-20 19:10:00
# 037-175_037-176         1973-03-20 19:29:00 1973-03-20 19:43:00
# 886-008                 1973-03-20 10:12:00 1973-03-20 11:55:00
# 421-018                 1973-03-20 17:20:00 1973-03-20 18:01:00
# 037-204_037-205         1973-03-20 19:53:00 1973-03-20 20:24:00
# 422-020                 1973-03-22 09:11:00 1973-03-22 10:35:00
# 422-033                 1973-03-22 13:57:00 1973-03-22 15:43:00
# 423-003                 1973-03-27 11:10:00 1973-03-27 13:30:00
# 890-019                 1973-03-30 12:02:00 1973-03-30 12:18:00
# 044-158                 1973-04-12 19:31:00 1973-04-12 19:48:00
# 428-019                 1973-04-14 08:55:00 1973-04-14 11:31:00
# 896-004                 1973-04-14 13:55:00 1973-04-14 14:13:00
# 896-005                 1973-04-14 14:24:00 1973-04-14 15:55:00
# 428-028                 1973-04-14 17:15:00 1973-04-14 18:45:00
# 038-034                 1973-04-14 23:02:00 1973-04-14 23:16:00
# 038-037                 1973-04-14 23:22:00 1973-04-14 23:53:00
# 896-006                 1973-04-15 10:05:00 1973-04-15 11:15:00
# 038-042_038-043         1973-04-15 15:27:00 1973-04-15 15:44:00
# 897-003                 1973-04-16 09:50:00 1973-04-16 09:59:00
# 897-004                 1973-04-16 10:00:00 1973-04-16 10:40:00
# 897-009                 1973-04-16 10:50:00 1973-04-16 11:04:00
# 897-011                 1973-04-16 12:00:00 1973-04-16 12:31:00
# 427-005_427-006         1973-04-16 15:27:00 1973-04-16 16:02:00
# 427-010                 1973-04-16 16:07:00 1973-04-16 16:35:00
# 898-006                 1973-04-17 09:47:00 1973-04-17 09:59:00
# 898-012                 1973-04-17 12:35:00 1973-04-17 14:20:00
# 898-023_899-001         1973-04-17 15:50:00 1973-04-17 16:35:00
# 429-003                 1973-04-17 17:20:00 1973-04-17 19:14:00
# 900-026                 1973-04-18 15:05:00 1973-04-18 15:23:00
# 902-001                 1973-04-19 09:31:00 1973-04-19 10:12:00
# 902-002_902-003         1973-04-19 10:12:00 1973-04-19 11:07:00
# 902-009                 1973-04-19 13:03:00 1973-04-19 13:30:00
# 429-015                 1973-04-19 15:45:00 1973-04-19 17:00:00
# 000-000_37d             1973-04-18 00:00:00 1973-04-18 00:00:00
# 429-018                 1973-04-19 17:15:00 1973-04-19 17:45:00
# 038-125_038-126         1973-04-19 21:37:00 1973-04-19 21:53:00
# 903-001                 1973-04-20 08:15:00 1973-04-20 08:39:00
# 903-006                 1973-04-20 11:07:00 1973-04-20 11:23:00
# 903-019                 1973-04-20 12:16:00 1973-04-20 12:34:00
# 430-004                 1973-04-25 11:06:00 1973-04-25 13:55:00
# 430-022                 1973-04-25 16:40:00 1973-04-25 17:30:00
# 038-150                 1973-04-25 18:57:00 1973-04-25 19:14:00
# 038-151                 1973-04-25 19:17:00 1973-04-25 19:19:00
# 038-154_038-155         1973-04-25 19:25:00 1973-04-25 19:39:00
# 038-156_038-157         1973-04-25 19:46:00 1973-04-25 19:53:00
# 905-008                 1973-04-26 08:55:00 1973-04-26 10:24:00
# 431-009                 1973-04-26 15:59:00 1973-04-26 21:03:00
# 442-001-069             1973-06-04 00:00:00 1973-06-04 00:00:00
# 039-080_039-081         1973-06-04 22:05:00 1973-06-04 22:20:00
# 039-083                 1973-06-04 22:21:00 1973-06-04 22:22:00
#
#                               time_diff  \
# 472-004_472-005_472-006 0 days 00:03:00
# 051-001                 0 days 00:50:00
# 472-021                 0 days 00:33:00
# 482-017_482-018         0 days 00:31:00
# 002-001_002-002         0 days 00:05:00
# 491-014                 0 days 00:00:00
# 538-015                 0 days 00:00:00
# 587-003                 0 days 00:42:00
# 601-033                 0 days 01:30:00
# 697-029                 0 days 01:00:00
# 342-027                 0 days 01:10:00
# 741-002                 0 days 01:35:00
# 741-010                 0 days 00:09:00
# 343-036                 0 days 00:25:00
# 347-004                 0 days 01:15:00
# 779-002                 0 days 00:53:00
# 000-000_35d             0 days 00:00:00
# 393-013_393-014         0 days 01:00:00
# 394-021_395-001         0 days 01:29:00
# 854-017                 0 days 01:04:00
# 855-010                 0 days 00:36:00
# 856-004                 0 days 00:26:00
# 858-003                 0 days 00:31:00
# 862-004                 0 days 00:30:00
# 862-006                 0 days 00:44:00
# 864-004                 0 days 00:25:00
# 865-014                 0 days 01:11:00
# 866-003                 0 days 00:27:00
# 878-014                 0 days 01:18:00
# 882-012                 0 days 00:45:00
# 884-007                 0 days 01:23:00
# 885-007                 0 days 01:10:00
# 037-175_037-176         0 days 00:14:00
# 886-008                 0 days 01:43:00
# 421-018                 0 days 00:41:00
# 037-204_037-205         0 days 00:31:00
# 422-020                 0 days 01:24:00
# 422-033                 0 days 01:46:00
# 423-003                 0 days 02:20:00
# 890-019                 0 days 00:16:00
# 044-158                 0 days 00:17:00
# 428-019                 0 days 02:36:00
# 896-004                 0 days 00:18:00
# 896-005                 0 days 01:31:00
# 428-028                 0 days 01:30:00
# 038-034                 0 days 00:14:00
# 038-037                 0 days 00:31:00
# 896-006                 0 days 01:10:00
# 038-042_038-043         0 days 00:17:00
# 897-003                 0 days 00:09:00
# 897-004                 0 days 00:40:00
# 897-009                 0 days 00:14:00
# 897-011                 0 days 00:31:00
# 427-005_427-006         0 days 00:35:00
# 427-010                 0 days 00:28:00
# 898-006                 0 days 00:12:00
# 898-012                 0 days 01:45:00
# 898-023_899-001         0 days 00:45:00
# 429-003                 0 days 01:54:00
# 900-026                 0 days 00:18:00
# 902-001                 0 days 00:41:00
# 902-002_902-003         0 days 00:55:00
# 902-009                 0 days 00:27:00
# 429-015                 0 days 01:15:00
# 000-000_37d             0 days 00:00:00
# 429-018                 0 days 00:30:00
# 038-125_038-126         0 days 00:16:00
# 903-001                 0 days 00:24:00
# 903-006                 0 days 00:16:00
# 903-019                 0 days 00:18:00
# 430-004                 0 days 02:49:00
# 430-022                 0 days 00:50:00
# 038-150                 0 days 00:17:00
# 038-151                 0 days 00:02:00
# 038-154_038-155         0 days 00:14:00
# 038-156_038-157         0 days 00:07:00
# 905-008                 0 days 01:29:00
# 431-009                 0 days 05:04:00
# 442-001-069             0 days 00:00:00
# 039-080_039-081         0 days 00:15:00
# 039-083                 0 days 00:01:00
#
#                                                        full_extracted_text  \
# 472-004_472-005_472-006  [[TRANSCRIPT PREPARED BY THE IMPEACHMENT INQUI...
# 051-001                  [[TRANSCRIPT PREPARED BY THE IMPEACHMENT INQUI...
# 472-021                  [[MEETING AMONG PRESIDENT RICHARD M. NIXON, JO...
# 482-017_482-018          [[TRANSCRIPT PREPARED BY THE IMPEACHMENT INQUI...
# 002-001_002-002          [[TRANSCRIPT PREPARED BY THE IMPEACHMENT INQUI...
# 491-014                  [[TRANSCRIPT OF A RECORDING OF A MEETING BETWE...
# 538-015                  [[TRANSCRIPT OF A RECORDING OF A PORTION OF A\...
# 587-003                  [[TRANSCRIPT OF A RECORDING OF A PORTION OF A\...
# 601-033                  [[TRANSCRIPT OF A RECORDING OF A\nMEETING IN T...
# 697-029                  [[Transcript of a Recording of a Meeting betwe...
# 342-027                  [[TRANSCRIPT OF A MEETING BETWEEN THE PRESIDEN...
# 741-002                  [[TRANSCRIPT OF A RECORDING OF A MEETING\nBETW...
# 741-010                  [[TRANSCRIPT OF A RECORDING OF A MEETING\nBETW...
# 343-036                  [[TRANSCRIPT OF A RECORDING OF A MEETING\nBETW...
# 347-004                  [[TRANSCRIPT OF EXCERPTS FROM THE RECORDING OF...
# 779-002                  [[TRANSCRIPT PREPARED BY THE IMPEACHMENT INQUI...
# 000-000_35d              [[Transcript of a Dictabelt Recording\nof a Co...
# 393-013_393-014          [[TRANSCRIPT OF A RECORDING OF A MEETING BETWE...
# 394-021_395-001          [[TRANSCRIPT OF RECORDING OF A MEETING BETWEEN...
# 854-017                  [[TRANSCRIPT OF A RECORDING OF A MEETING\nBETW...
# 855-010                  [[TRANSCRIPT OF A RECORDING, BETWEEN THE\nPRES...
# 856-004                  [[Transcript of a Recording of a Meeting\nbetw...
# 858-003                  [[Transcript of a Recording of a Conversation\...
# 862-004                  [[TRANSCRIPT OF A RECORDING OF A PORTION OF A ...
# 862-006                  [[TRANSCRIPT OF A RECORDING OF A MEETING IN TH...
# 864-004                  [[TRANSCRIPT OF A RECORDING OF A MEETING\nBETW...
# 865-014                  [[TRANSCRIPT OF A RECORDING OF A MEETING BETWE...
# 866-003                  [[TRANSCRIPT OF A RECORDING OF A MEETING\nOF M...
# 878-014                  [[TRANSCRIPT PREPARED BY THE IMPEACHMENT\nINQU...
# 882-012                  [[TRANSCRIPT OF RECORDING OF A MEETING AMONG\n...
# 884-007                  [[TRANSCRIPT OF A RECORDING OF A MEETING BETWE...
# 885-007                  [[TRANSCRIPT OF A RECORDING OF A MEETING\nBETW...
# 037-175_037-176          [[TRANSCRIPT OF A RECORDING OF A TELEPHONE\nCO...
# 886-008                  [[TRANSCRIPT PREPARED BY THE IMPEACHMENT INQUI...
# 421-018                  [[TRANSCRIPT PREPARED BY THE IMPEACHMENT INQUI...
# 037-204_037-205          [[TRANSCRIPT OF A TELEPHONE CONVERSATION\nBETW...
# 422-020                  [[TRANSCRIPT OF A RECORDING OF A MEETING\nBETW...
# 422-033                  [[TRANSCRIPT PREPARED BY THE IMPEACHMENT\nINQU...
# 423-003                  [[TRANSCRIPT OF A RECORDING OF A MEETING AMONG...
# 890-019                  [[TRANSCRIPT OF A RECORDING OF A MEETING AMONG...
# 044-158                  [[TRANSCRIPT OF A RECORDING OF A TELEPHONE\nCO...
# 428-019                  [[TRANSCRIPT OF A RECORDING OF A MEETING AMONG...
# 896-004                  [[TRANSCRIPT OF RECORDING OF A MEETING BETWEEN...
# 896-005                  [[TRANSCRIPT OF A RECORDING, OF A MEETING\nAMO...
# 428-028                  [[TRANSCRIPT OF A RECORDING OF A MEETING\nBETW...
# 038-034                  [[TRANSCRIPT OF A TELEPHONE\nCONVERSATION BETW...
# 038-037                  [[TRANSCRIPT OF A RECORDING OF A TELEPHONE\nCO...
# 896-006                  [[TRANSCRIPT OF A RECORDING OF A MEETING BETWE...
# 038-042_038-043          [[TRANSCRIPT OF A RECORDING OF ATELEPHONE\nCON...
# 897-003                  [[TRANSCRIPT OF A RECORDING OF A MEETING AMONG...
# 897-004                  [[TRANSCRIPT PREPARED BY THE IMPEACHMENT INQUI...
# 897-009                  [[TRANSCRIPT OF A RECORDING OF A MEETING\nBETW...
# 897-011                  [[TRANSCRIPT OF A MEETING BETWEEN THE\nPRESIDE...
# 427-005_427-006          [[TRANSCRIPT OF A RECORDING OF A MEETING\nBETW...
# 427-010                  [[TRANSCRIPT PREPARED BY THE IMPEACHMENT INQUI...
# 898-006                  [[TRANSCRIPT OF A MEETING BETWEEN THE\nPRESIDE...
# 898-012                  [[TRANSCRIPT OF A RECORDING OF A MEETING\nBETW...
# 898-023_899-001          [[TRANSCRIPT OF A RECORDING OF A MEETING AMONG...
# 429-003                  [[TRANSCRIPT OF A RECORDING OF A MEETING AMONG...
# 900-026                  [[TRANSCRIPT OF A RECORDING OF A MEETING BETWE...
# 902-001                  [[TRANSCRIPT OF A RECORDING OF A MEETING AMONG...
# 902-002_902-003          [[TRANSCRIPT OF A RECORDING OF A MEETING BETWE...
# 902-009                  [[TRANSCRIPT OF A RECORDING OF A MEETING BETWE...
# 429-015                  [[TRANSCRIPT OF A TAPE RECORDING OF A\nCONVERS...
# 000-000_37d              [[TRANSCRIPT OF A RECORDING OF A\nTELEPHONE CO...
# 429-018                  [[TRANSCRIPT OF A CONVBRSATION BETWEEN THE\nPR...
# 038-125_038-126          [[TRANSCRIPT OF A RECORDING OF A TELEPHONE CON...
# 903-001                  [[TRANSCRIPT OF A RECORDING OF A MEETING\nBETW...
# 903-006                  [[TRANSCRIPT OF A RECORDING OF A MEETING\nBETW...
# 903-019                  [[TRANSCRIPT OF A MEETING AMONG THE PRESIDENT,...
# 430-004                  [[TRANSCRIPT OF A MEETING AMONG THE PRESIDENT,...
# 430-022                  [[TRANSCRIPT OF A RECORDING OF A MEETING\nBETW...
# 038-150                  [[TRANSCRIPT OF A RECORDING OF A TELEPHONE\nCO...
# 038-151                  [[TRANSCRIPT OF A RECORDING OF A TELEPHONE CON...
# 038-154_038-155          [[TRANSCRIPT OF A RECORDING OF A TELEPHONE\nCO...
# 038-156_038-157          [[TRANSCRIPT OF A RECORDING OF A TELEPHONE\nCO...
# 905-008                  [[TRANSCRIPT OF A MEETING BETWEEN THE\nPRESIDE...
# 431-009                  [[TRANSCRIPT OF A RECORDING OF A MEETING AMONG...
# 442-001-069              [[***   DRAFT ***\nTRANSCRIPT PREPARED BY THE ...
# 039-080_039-081          [[TRANSCRIPT OF A RECORDING OF A TELEPHONE\nCO...
# 039-083                  [[TRANSCRIPT OF A TELEPHONE CONVERSATION\nBETW...
#
#                                                                    dropped  \
# 472-004_472-005_472-006  [Picks up telephone., Hangs up., Telephone buz...
# 051-001                  [Laughter, unintelligible, Laughter, Unintelli...
# 472-021                  [coughing, unintelligible, unintelligible, Sev...
# 482-017_482-018          [Picks up telephone., To telephone operator, u...
# 002-001_002-002          [Laughs, Unintelligible, Laughs, unintelligibl...
# 491-014                  [Unintelligible, tape noise, Laughs, Tape Nois...
# 538-015                  [unintelligible, unintelligible, Unintelligibl...
# 587-003                  [unintelligible, unintelligible, unintelligibl...
# 601-033                  [unintelligible, unintelligible, Unintelligibl...
# 697-029                  [Unintelligible, Unintelligible, unintelligibl...
# 342-027                  [Unintelligible, unintelligible, Unintelligibl...
# 741-002                  [Unintelligible speech, Unintelligible, Twenty...
# 741-010                  [On the phone, Unintelligible, 40 second pause...
# 343-036                  [Background noise, unintelligible, unintelligi...
# 347-004                  [unintelligible, both speak at once, Unintelli...
# 779-002                  [Unintelligible, unintelligible, Unintelligibl...
# 000-000_35d              [unintelligible, Laughs, Unintelligible, Laugh...
# 393-013_393-014          [Noise, Unintelligible, Unintelligible, uninte...
# 394-021_395-001          [Unintelligible, unintelligible, unintelligibl...
# 854-017                  [Unintelligible, Unintelligible, unintelligibl...
# 855-010                  [Noise, Noise, unintelligible, unintelligible,...
# 856-004                  [unintelligible, cont., Ummm, cont., both talk...
# 858-003                  [Laughs, Unintelligible, cont., unintelligible...
# 862-004                  [unintelligible, pause, unintelligible/REMOVED...
# 862-006                  [Unintelligible, laughing, Pause, writing nois...
# 864-004                  [unintelligible, unintelligible, Unintelligibl...
# 865-014                  [Clears throat, unintelligible, unintelligible...
# 866-003                  [unintelligible, Unintelligible, unintelligibl...
# 878-014                  [unintelligible, Unintelligible, unintelligibl...
# 882-012                  [unintelligible, unintelligible, coughs, Conti...
# 884-007                  [unintelliqible, unintelligible, unintelligibl...
# 885-007                  [unintelligible, Unintelligible, Pause, uninte...
# 037-175_037-176          [Laughs, Unintelligible, cough, unintelligible...
# 886-008                  [Sighs, unintelligible, Unintelligible, Uninte...
# 421-018                  [Unintelligible, unintelligible, unintelligibl...
# 037-204_037-205          [Pause, Laughs, unintelligible, clears throat,...
# 422-020                  [Noise, Unintelliqible, unintelligible, Uninte...
# 422-033                  [Unintelligible, unintelligible, Unintelligibl...
# 423-003                  [unintelligible, Unintelligible, unintelligibl...
# 890-019                  [Unintelligible, Loud Noise, Pause, Unintellig...
# 044-158                  [Unintelligible, laughs, laughs, unintelligibl...
# 428-019                  [Unintelligible, noise, unintelligible, Uninte...
# 896-004                  [Unintelligible, Unintelligible, unintelligibl...
# 896-005                  [Unintelligible, Unintelligible, Unintelligibl...
# 428-028                  [Tape noise occurs throughout, unintelligible,...
# 038-034                  [Pause, unintelligible, laughs, pause, Pause, ...
# 038-037                  [clears throat, clears throat, laughs, unintel...
# 896-006                  [Phone rings, Unintelligible, unintelligible, ...
# 038-042_038-043          [clears throat, laughs, unintelligible, Pause,...
# 897-003                  [Unintelligible, Unintelligible, unintelligibl...
# 897-004                  [unintelligible, unintelligible, Clears throat...
# 897-009                  [Noise, unintelligible, unintelligible, Uninte...
# 897-011                  [Unintelligible, Unintelligible, Pause, uninte...
# 427-005_427-006          [Ringing of telephone, Pause, Pause, unintelli...
# 427-010                  [Unintelligible, Unintelligible, unintelligibl...
# 898-006                  [Door Closing in Background, unintelligible, u...
# 898-012                  [unintelligible, Unintelligible, unintelligibl...
# 898-023_899-001          [Noise, 45 Second Pause, unintelligible, Pause...
# 429-003                  [unintelligible, Unintelligible, unintelligibl...
# 900-026                  [unintelligible, unintelligible, Sighs, uninte...
# 902-001                  [unintelligible, unintelligible, unintelligibl...
# 902-002_902-003          [unintelligible, unintelligible, unintelligibl...
# 902-009                  [pause, Unintelligible, unintelligible, Uninte...
# 429-015                  [Unintelligible, Unintelligible, unintelligibl...
# 000-000_37d                                        [CONT., unintelligible]
# 429-018                  [Unintelligible, Unintelligible, tape noise, u...
# 038-125_038-126          [Unintelligible, Pause, unintelligible, uninte...
# 903-001                  [unintelligible, laughs, cough, unintelligible...
# 903-006                  [Unintelligible, with noise, unintelligible, u...
# 903-019                  [unintelligible, unintelligible, unintelligibl...
# 430-004                  [Unintelligible, Unintelligible, Tape noise, u...
# 430-022                  [tape noise., Unintelligible with tape noise, ...
# 038-150                  [unintelligible, unintelligible, unintelligibl...
# 038-151                                    [clears throat, unintelligible]
# 038-154_038-155          [phonetic, phonetic, unintelligible, unintelli...
# 038-156_038-157          [Unintelligible, unintelligible, unintelligibl...
# 905-008                  [Unintelligible, unintelligible, unintelligibl...
# 431-009                  [20 second pause, Unintelligible, unintelligib...
# 442-001-069              [Noise, 33, 684, Noise, Pause.  Bull enters, u...
# 039-080_039-081          [Unintelligible, CONTINUED, unintelligible, un...
# 039-083                                                                 []
#
#                                                              speech_header  \
# 472-004_472-005_472-006  TRANSCRIPT PREPARED BY THE IMPEACHMENT INQUIRY...
# 051-001                  TRANSCRIPT PREPARED BY THE IMPEACHMENT INQUIRY...
# 472-021                  MEETING AMONG PRESIDENT RICHARD M. NIXON, JOHN...
# 482-017_482-018          TRANSCRIPT PREPARED BY THE IMPEACHMENT INQUIRY...
# 002-001_002-002          TRANSCRIPT PREPARED BY THE IMPEACHMENT INQUIRY...
# 491-014                  TRANSCRIPT OF A RECORDING OF A MEETING BETWEEN...
# 538-015                  TRANSCRIPT OF A RECORDING OF A PORTION OF A ME...
# 587-003                  TRANSCRIPT OF A RECORDING OF A PORTION OF A ME...
# 601-033                  TRANSCRIPT OF A RECORDING OF A MEETING IN THE ...
# 697-029                  Transcript of a Recording of a Meeting between...
# 342-027                  TRANSCRIPT OF A MEETING BETWEEN THE PRESIDENT ...
# 741-002                  TRANSCRIPT OF A RECORDING OF A MEETING BETWEEN...
# 741-010                  TRANSCRIPT OF A RECORDING OF A MEETING BETWEEN...
# 343-036                  TRANSCRIPT OF A RECORDING OF A MEETING BETWEEN...
# 347-004                  TRANSCRIPT OF EXCERPTS FROM THE RECORDING OF A...
# 779-002                  TRANSCRIPT PREPARED BY THE IMPEACHMENT INQUIRY...
# 000-000_35d              Transcript of a Dictabelt Recording of a Conve...
# 393-013_393-014          TRANSCRIPT OF A RECORDING OF A MEETING BETWEEN...
# ...
# 890-019                  TRANSCRIPT OF A RECORDING OF A MEETING AMONG T...
# 044-158                  TRANSCRIPT OF A RECORDING OF A TELEPHONE CONVE...
# 428-019                  TRANSCRIPT OF A RECORDING OF A MEETING AMONG T...
# 896-004                  TRANSCRIPT OF RECORDING OF A MEETING BETWEEN T...
# 896-005                  TRANSCRIPT OF A RECORDING, OF A MEETING AMONG ...
# 428-028                  TRANSCRIPT OF A RECORDING OF A MEETING BETWEEN...
# 038-034                  TRANSCRIPT OF A TELEPHONE CONVERSATION BETWEEN...
# 038-037                  TRANSCRIPT OF A RECORDING OF A TELEPHONE CONVE...
# 896-006                  TRANSCRIPT OF A RECORDING OF A MEETING BETWEEN...
# 038-042_038-043          TRANSCRIPT OF A RECORDING OF ATELEPHONE CONVER...
# 897-003                  TRANSCRIPT OF A RECORDING OF A MEETING AMONG T...
# 897-004                  TRANSCRIPT PREPARED BY THE IMPEACHMENT INQUIRY...
# 897-009                  TRANSCRIPT OF A RECORDING OF A MEETING BETWEEN...
# 897-011                  TRANSCRIPT OF A MEETING BETWEEN THE PRESIDENT ...
# 427-005_427-006          TRANSCRIPT OF A RECORDING OF A MEETING BETWEEN...
# 427-010                  TRANSCRIPT PREPARED BY THE IMPEACHMENT INQUIRY...
# 898-006                  TRANSCRIPT OF A MEETING BETWEEN THE PRESIDENT ...
# 898-012                  TRANSCRIPT OF A RECORDING OF A MEETING BETWEEN...
# 898-023_899-001          TRANSCRIPT OF A RECORDING OF A MEETING AMONG T...
# 429-003                  TRANSCRIPT OF A RECORDING OF A MEETING AMONG T...
# 900-026                  TRANSCRIPT OF A RECORDING OF A MEETING BETWEEN...
# 902-001                  TRANSCRIPT OF A RECORDING OF A MEETING AMONG T...
# 902-002_902-003          TRANSCRIPT OF A RECORDING OF A MEETING BETWEEN...
# 902-009                  TRANSCRIPT OF A RECORDING OF A MEETING BETWEEN...
# 429-015                  TRANSCRIPT OF A TAPE RECORDING OF A CONVERSATI...
# 000-000_37d              TRANSCRIPT OF A RECORDING OF A TELEPHONE CONVE...
# 429-018                  TRANSCRIPT OF A CONVBRSATION BETWEEN THE PRESI...
# 038-125_038-126          TRANSCRIPT OF A RECORDING OF A TELEPHONE CONVE...
# 903-001                  TRANSCRIPT OF A RECORDING OF A MEETING BETWEEN...
# 903-006                  TRANSCRIPT OF A RECORDING OF A MEETING BETWEEN...
# 903-019                  TRANSCRIPT OF A MEETING AMONG THE PRESIDENT, H...
# 430-004                  TRANSCRIPT OF A MEETING AMONG THE PRESIDENT, H...
# 430-022                  TRANSCRIPT OF A RECORDING OF A MEETING BETWEEN...
# 038-150                  TRANSCRIPT OF A RECORDING OF A TELEPHONE CONVE...
# 038-151                  TRANSCRIPT OF A RECORDING OF A TELEPHONE CONVE...
# 038-154_038-155          TRANSCRIPT OF A RECORDING OF A TELEPHONE CONVE...
# 038-156_038-157          TRANSCRIPT OF A RECORDING OF A TELEPHONE CONVE...
# 905-008                  TRANSCRIPT OF A MEETING BETWEEN THE PRESIDENT ...
# 431-009                  TRANSCRIPT OF A RECORDING OF A MEETING AMONG T...
# 442-001-069              ***   DRAFT *** TRANSCRIPT PREPARED BY THE IMP...
# 039-080_039-081          TRANSCRIPT OF A RECORDING OF A TELEPHONE CONVE...
# 039-083                  TRANSCRIPT OF A TELEPHONE CONVERSATION BETWEEN...
#
#                                                       speech_flat_norepeat  \
# 472-004_472-005_472-006  PRESIDENT: [Picks up telephone.] Secretary Con...
# 051-001                  PRESIDENT: Let me get around to say hello to e...
# 472-021                  PRESIDENT: Hi, Phil, how are you?\nCAMPBELL: M...
# 482-017_482-018          PRESIDENT: Kleindienst is  in this? [Picks up ...
# 002-001_002-002          PRESIDENT: Dick Kleindienst.\nSECRETARY: Thank...
# 491-014                  PRESIDENT: Picked up them all right.\nHALDEMAN...
# 538-015                  NIXON: Uh, I wanted to, uh, check with you bef...
# 587-003                  MITCHELL: Mr. President, two other quick thing...
# 601-033                  EHRLICHMAN: A lot of, uh\nPRESIDENT: Yeah comp...
# 697-029                  Colson: ...I don't know, maybe the, maybe the ...
# 342-027                  COLSON:  Sir.\nPRESIDENT: Hi.  Now I hope ever...
# 741-002                  PRESIDENT: (Unintelligible) I've told that you...
# 741-010                  HALDEMAN: (On the phone) (Unintelligible) 111n...
# 343-036                  HALDEMAN: Well, it’s no problem.  Had the…two ...
# 347-004                  HALDEMAN: Well, there's another factor.  The l...
# 779-002                  PRESIDENT: [Unintelligible]\nHALDEMAN: John, h...
# 000-000_35d              COLSON: Hello.\nHUNT: Hi.\nCOLSON: How we doin...
# 393-013_393-014          COLSON: And that's when that week he's going t...
# 394-021_395-001          PRESIDENT: (Unintelligible) Incidentially, uh,...
# 854-017                  PRESIDENT: (Unintelligible) that's come from t...
# 855-010                  PRESIDENT: (Noise) Going on your way? (Noise)\...
# 856-004                  Ehrlichman: And then there'll be a committee b...
# 858-003                  President: Hi.  How are you.\nGray: Mr. Presid...
# 862-004                  President: (unintelligible)\nNow on Kleindiens...
# 862-006                  PRESIDENT: Hello Dick.  How are you?\nKLEINDIE...
# 864-004                  PRESIDENT: Good afternoon, John, how are you?\...
# 865-014                  DEAN: Good morning, sir.\nPRESIDENT: Oh, hi.\n...
# 866-003                  DEAN: Good morning Mr. President.\nPRESIDENT: ...
# 878-014                  HALDEMAN: Say, did you raise the question with...
# 882-012                  PRESIDENT: Well, I was wondering what your lat...
# 884-007                  PRESIDENT: What I think, what it really gets d...
# 885-007                  PRESIDENT: Well, I'm trying to figure out with...
# 037-175_037-176          PRESIDENT: John Dean, please.\nOperator: Yes, ...
# 886-008                  PRESIDENT: John, sit down, sit down.\nDEAN: Go...
# 421-018                  PRESIDENT: [Unintelligible] to this morning.\n...
# 037-204_037-205          OPERATOR: Yes?\nPRESIDENT: Mr. Colson, please....
# 422-020                  PRESIDENT: (Unintelliqible) Who, uh, has talke...
# 422-033                  PRESIDENT: Hello John, how are you? [Unintelli...
# 423-003                  EHRLICHMAN: This story and, uh, this one, uh, ...
# 890-019                  EHRLICHMAN: (Unintelligible) (Loud Noise) We h...
# 044-158                  PRESIDENT: (Unintelligible)\nCOLSON: No I didn...
# 428-019                  PRESIDENT: Jack, uh, do, uh, did you reach any...
# 896-004                  PRESIDENT: Garden tour?\nHALDEMAN: (Unintellig...
# 896-005                  PRESIDENT: All finished?\nEHRLICHMAN: Yes air....
# 428-028                  EHRLICHMAN: Well, he and his two lawyers who a...
# 038-034                  PRESIDENT: I just, uh, Bebe is over here overn...
# 038-037                  PRESIDENT: Just wanted to see what your plans ...
# 896-006                  EHRLICHMAN:  (Unintelligible)\nPRESIDENT: Poor...
# 038-042_038-043          UNIDENTIFIED: Okay, be right there.  Okay Budd...
# 897-003                  PRESIDENT: (Unintelligible) John, I want him t...
# 897-004                  PRESIDENT: Hi John, how are you?\nDEAN: Good m...
# 897-009                  HALDEMAN: The scenario works out pretty well. ...
# 897-011                  PRESIDENT: Do you have any further thoughts on...
# 427-005_427-006          PRESIDENT: Yeah.  Have you made any progress o...
# 427-010                  PRESIDENT: Hi, John.\nDEAN: Yes, sir.\nPRESIDE...
# 898-006                  HALDEMAN: Yes, sir.\nPRESIDENT: Uh, hello.  I,...
# 898-012                  PRESIDENT: Where did we come out?\nEHRLICHMAN:...
# 898-023_899-001          EHRLICHMAN: (Noise) This is John Ehrlichman fo...
# 429-003                  PRESIDENT: Come in.\nROGERS: Mr. President.\nP...
# 900-026                  PRESIDENT: I talked to (unintelligible) before...
# 902-001                  PRESIDENT: Well, what I wanted to say was this...
# 902-002_902-003          PRESIDENT: Fine.  I'll be finished --ulould yo...
# 902-009                  EHRLICHMAN: Mr. President.\nPRESIDENT: John, J...
# 429-015                  MOORE: (Unintelligible).\nPRESIDENT: Come in, ...
# 000-000_37d              EHRLICHMAN: 'Lo!\nKALMBACH: Hi!\nEHRLICHMAN: H...
# 429-018                  UNIDENTIFIED: (Unintelligible)\nEHRLICHMAN: (U...
# 038-125_038-126          PRESIDENT: Haldeman please.\nOPERATOR:  (Unint...
# 903-001                  PRESIDENT: I don't know whether we can do anyt...
# 903-006                  HALDEMAN: Yep.  This is exactly the right thin...
# 903-019                  PRESIDENT: Any further thoughts about this?\nE...
# 430-004                  EHRLICHMAN: Hi.\nPRESIDENT: Well, I understand...
# 430-022                  PRESIDENT: Hi. Come on in.\nHALDEMAN: Well, th...
# 038-150                  PRESIDENT: Hello.\nHALDEMAN: Yes sir.\nPRESIDE...
# 038-151                  NIXON: Ya.\nSECRETARY: I have Mr. Ehrlichman n...
# 038-154_038-155          OPERATOR: Thank you.\nPRESIDENT: Yeah.\nEHRLIC...
# 038-156_038-157          PRESIDENT: (Unintelligible)\nOPERATOR: Thank y...
# 905-008                  PRESIDENT: Hi.\nHALDEMAN: Hi.\nHALDEMAN: Just ...
# 431-009                  PRESIDENT: Bob, how’re ya doin'?\nHALDEMAN: Ok...
# 442-001-069              PRESIDENT: Bull, please.  Steve.  Hello.  Than...
# 039-080_039-081          OPERATOR: Yes, please.\nPRESIDENT: Mr. Haldema...
# 039-083                  PRESIDENT: Bob?\nOPERATOR: Just a moment.  Her...
#
#                                                               speech_final
# 472-004_472-005_472-006    Secretary Connally please.    Mr. President,...
# 051-001                   Let me get around to say hello to everybody. ...
# 472-021                   Hi, Phil, how are you?  Mr. President.  Sorry...
# 482-017_482-018           Kleindienst is  in this?   Yes.   Dick Kleind...
# 002-001_002-002           Dick Kleindienst.  Thank you, Mr. President. ...
# 491-014                   Picked up them all right.  Yesterday.  How's ...
# 538-015                   Uh, I wanted to, uh, check with you before yo...
# 587-003                   Mr. President, two other quick things if you ...
# 601-033                   A lot of, uh  Yeah complicated matters  heavy...
# 697-029                   ...I don't know, maybe the, maybe the ITT thi...
# 342-027                    Sir.  Hi.  Now I hope everybody is not going...
# 741-002                    I've told that you've got, they've got magni...
# 741-010                     111nere are they? Okay.  I'll be up in just...
# 343-036                   Well, it’s no problem.  Had the…two of them i...
# 347-004                   Well, there's another factor.  The longer you...
# 779-002                     John, he is one of the quiet guys that gets...
# 000-000_35d               Hello.  Hi.  How we doin'?  Well, uh, about a...
# 393-013_393-014           And that's when that week he's going to New Y...
# 394-021_395-001            Incidentially, uh, Haldeman was telling, uh,...
# 854-017                    that's come from the other you can't get Web...
# 855-010                    Going on your way?   Yes, sir.  I think I've...
# 856-004                   And then there'll be a committee bill which w...
# 858-003                   Hi.  How are you.  Mr. President.  How are yo...
# 862-004                    Now on Kleindienst - uh, I want to talk with...
# 862-006                   Hello Dick.  How are you?  How are you feelin...
# 864-004                   Good afternoon, John, how are you?  Pretty go...
# 865-014                   Good morning, sir.  Oh, hi.  How are you?  Oh...
# 866-003                   Good morning Mr. President.  Hi, how are you?...
# 878-014                   Say, did you raise the question with the Pres...
# 882-012                   Well, I was wondering what your latest develo...
# 884-007                   What I think, what it really gets down to, ba...
# 885-007                   Well, I'm trying to figure out with Ehrlichma...
# 037-175_037-176           John Dean, please.  Yes, Mr. President.   Hel...
# 886-008                   John, sit down, sit down.  Good morning.  Wel...
# 421-018                    to this morning.  Well, you go round and rou...
# 037-204_037-205           Yes?  Mr. Colson, please.  Thank you, Mr. Pre...
# 422-020                    Who, uh, has talked at all to, uh,  Kleindie...
# 422-033                   Hello John, how are you?   Mr. President  Nix...
# 423-003                   This story and, uh, this one, uh, this, this ...
# 890-019                     We have, I think, a useful statement that h...
# 044-158                     No I didn't and I got nothing on Watergate ...
# 428-019                   Jack, uh, do, uh, did you reach any conclusio...
# 896-004                   Garden tour?      Did you? that's alright I'l...
# 896-005                   All finished?  Yes air.  All finished.  He is...
# 428-028                   Well, he and his two lawyers who are ver- ver...
# 038-034                   I just, uh, Bebe is over here overnight and I...
# 038-037                   Just wanted to see what your plans were tomor...
# 896-006                      Poor guy.  Who all have you seen this morn...
# 038-042_038-043           Okay, be right there.  Okay Buddy.  Yes, plea...
# 897-003                    John, I want him to, uh, to uh, before I see...
# 897-004                   Hi John, how are you?  Good morning.  Good mo...
# 897-009                   The scenario works out pretty well.  Yeah   W...
# 897-011                   Do you have any further thoughts on, uh, how,...
# 427-005_427-006           Yeah.  Have you made any progress on that thi...
# 427-010                   Hi, John.  Yes, sir.  Well, did you have a bu...
# 898-006                   Yes, sir.  Uh, hello.  I, uh, sit down, that'...
# 898-012                   Where did we come out?  Well, we got two thin...
# 898-023_899-001            This is John Ehrlichman for Bill Timmons.  ....
# 429-003                   Come in.  Mr. President.  Yeah.  Well, have y...
# 900-026                   I talked to  before I talked to Petersen.  He...
# 902-001                   Well, what I wanted to say was this uh, other...
# 902-002_902-003           Fine.  I'll be finished --ulould you tell him...
# 902-009                   Mr. President.  John, John, how are you? EHRL...
# 429-015                   .  Come in, come in.  Fine.  Nice to see you....
# 000-000_37d               'Lo!  Hi!  How are you?  I'm, I'm pretty good...
# 429-018                      out of the shower bath. I'm getting kinda ...
# 038-125_038-126           Haldeman please.    Thank you.   Hello  Yes s...
# 903-001                   I don't know whether we can do anything about...
# 903-006                   Yep.  This is exactly the right thing to do t...
# 903-019                   Any further thoughts about this?  We just had...
# 430-004                   Hi.  Well, I understand the weather was as go...
# 430-022                   Hi. Come on in.  Well, that is hard work. Goo...
# 038-150                   Hello.  Yes sir.  Oh, Bob, you got home?  Yea...
# 038-151                   Ya.  I have Mr. Ehrlichman now, sir. I have M...
# 038-154_038-155           Thank you.  Yeah.  Yes sir.  I wanted you to ...
# 038-156_038-157             Thank you  Ya  Yes, sir.  Is there any, uh,...
# 905-008                   Hi.  Hi.  Just to show you somebody still has...
# 431-009                   Bob, how’re ya doin'?  Okay.   Had a long day...
# 442-001-069               Bull, please.  Steve.  Hello.  Thank you.   I...
# 039-080_039-081           Yes, please.  Mr. Haldeman, please.  Thank yo...
# 039-083                   Bob?  Just a moment.  Here you are.  Sorry to...

# %% [markdown]
# ## Store Data

# %% [markdown]
# ### Pickle the cleaned dataframes

# %%
# pickle initial dataframe to avoid processing datagrooming
output = open('cleaned_WSPF.pkl', 'wb')
sys.setrecursionlimit(100000)

pickle.dump(df_all, output)

output.close()

# %% [markdown]
# ### Pickle Import block
# Copy this cell to any notebook to retrieve and unpickle the dataframes

# %%
import pprint, pickle
import pandas as pd

# unpickle preserved dataframes to continue EDA and Statistical Analysis
pkl_file = open('cleaned_WSPF.pkl', 'rb')

df_all_wspf = pickle.load(pkl_file)
print("\n~~~df_all_wspf~~~\n")
print(df_all_wspf.info())

# Expected Results:

# Index: 81 entries, 472-004_472-005_472-006 to 039-083
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype          
# ---  ------                --------------  -----          
#  0   conversation_number   81 non-null     object         
#  1   cassette_number       81 non-null     object         
#  2   location              81 non-null     object         
#  3   participants          81 non-null     object         
#  4   minutes               81 non-null     object         
#  5   txtdate               81 non-null     object         
#  6   date                  81 non-null     datetime64[ns] 
#  7   start_dtime           81 non-null     datetime64[ns] 
#  8   end_dtime             81 non-null     datetime64[ns] 
#  9   time_diff             81 non-null     timedelta64[ns]
#  10  full_extracted_text   81 non-null     object         
#  11  dropped               81 non-null     object         
#  12  speech_header         81 non-null     object         
#  13  speech_flat_norepeat  81 non-null     object         
#  14  speech_final          81 non-null     object         
# dtypes: datetime64[ns](3), object(11), timedelta64[ns](1)
# Out:
# ~~~df_all_wspf~~~
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 81 entries, 472-004_472-005_472-006 to 039-083
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   conversation_number   81 non-null     object
#  1   cassette_number       81 non-null     object
#  2   location              81 non-null     object
#  3   participants          81 non-null     object
#  4   minutes               81 non-null     object
#  5   txtdate               81 non-null     object
#  6   date                  81 non-null     datetime64[ns]
#  7   start_dtime           81 non-null     datetime64[ns]
#  8   end_dtime             81 non-null     datetime64[ns]
#  9   time_diff             81 non-null     timedelta64[ns]
#  10  full_extracted_text   81 non-null     object
#  11  dropped               81 non-null     object
#  12  speech_header         81 non-null     object
#  13  speech_flat_norepeat  81 non-null     object
#  14  speech_final          81 non-null     object
# dtypes: datetime64[ns](3), object(11), timedelta64[ns](1)
# memory usage: 10.1+ KB
# None
